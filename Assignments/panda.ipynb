# %%
import numpy as np
import pandas as pd

# %%
pd.DataFrame([1,2,3],columns=['A'],index= ['P','Q','R'])
# Out:
#    A
# P  1
# Q  2
# R  3

# %%
pd.DataFrame({"Months":["march","april"],"Sales":[20,40]})
# Out:
#   Months  Sales
# 0  march     20
# 1  april     40

# %%
df=pd.DataFrame(np.random.randint(0,100,(2,2)))
df
# Out:
#     0   1
# 0  95  41
# 1  83  19

# %%
df.shape
# Out:
# (2, 2)

# %%
df=pd.read_csv("dataset.csv")
df.head(2)
# Out:
#    Row ID        Order ID Order Date   Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2016-152156  8/11/2016  11/11/2016  Second Class    CG-12520
# 1       2  CA-2016-152156  8/11/2016  11/11/2016  Second Class    CG-12520
#
#   Customer Name   Segment        Country       City  ... Postal Code  Region  \
# 0   Claire Gute  Consumer  United States  Henderson  ...       42420   South
# 1   Claire Gute  Consumer  United States  Henderson  ...       42420   South
#
#         Product ID   Category Sub-Category  \
# 0  FUR-BO-10001798  Furniture    Bookcases
# 1  FUR-CH-10000454  Furniture       Chairs
#
#                                         Product Name   Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.96         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94         3
#
#    Discount    Profit
# 0       0.0   41.9136
# 1       0.0  219.5820
#
# [2 rows x 21 columns]

# %%
df.tail(2)
# Out:
#       Row ID        Order ID Order Date Ship Date       Ship Mode Customer ID  \
# 9992    9993  CA-2017-121258  26/2/2017  3/3/2017  Standard Class    DB-13060
# 9993    9994  CA-2017-119914   4/5/2017  9/5/2017    Second Class    CC-12220
#
#      Customer Name   Segment        Country         City  ... Postal Code  \
# 9992   Dave Brooks  Consumer  United States   Costa Mesa  ...       92627
# 9993  Chris Cortes  Consumer  United States  Westminster  ...       92683
#
#       Region       Product ID         Category Sub-Category  \
# 9992    West  OFF-PA-10004041  Office Supplies        Paper
# 9993    West  OFF-AP-10002684  Office Supplies   Appliances
#
#                                            Product Name   Sales  Quantity  \
# 9992  It's Hot Message Books with Stickers, 2 3/4" x 5"   29.60         4
# 9993  Acco 7-Outlet Masterpiece Power Center, Wihtou...  243.16         2
#
#       Discount  Profit
# 9992       0.0  13.320
# 9993       0.0  72.948
#
# ...

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=9994, step=1)

# %%
df[['Row ID','Order ID','State']].head(2)
# Out:
#    Row ID        Order ID     State
# 0       1  CA-2016-152156  Kentucky
# 1       2  CA-2016-152156  Kentucky

# %%
df.iloc[2:6,:10]
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 2       3  CA-2016-138688   12/6/2016   16/6/2016    Second Class    DV-13045
# 3       4  US-2015-108966  11/10/2015  18/10/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  11/10/2015  18/10/2015  Standard Class    SO-20335
# 5       6  CA-2014-115812    9/6/2014   14/6/2014  Standard Class    BH-11710
#
#      Customer Name    Segment        Country             City
# 2  Darrin Van Huff  Corporate  United States      Los Angeles
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 5  Brosina Hoffman   Consumer  United States      Los Angeles

# %%
df.dtypes
# Out:
# Row ID             int64
# Order ID          object
# Order Date        object
# Ship Date         object
# Ship Mode         object
# Customer ID       object
# Customer Name     object
# Segment           object
# Country           object
# City              object
# State             object
# Postal Code        int64
# Region            object
# Product ID        object
# Category          object
# Sub-Category      object
# Product Name      object
# Sales            float64
# Quantity           int64
# Discount         float64
# Profit           float64
# dtype: object

# %%
np.iinfo(np.int8)
# Out:
# iinfo(min=-128, max=127, dtype=int8)

# %%
int(np.finfo(np.float16).min)
# Out:
# -65504

# %%
df.select_dtypes(include=['int16','float64']).head(2)
# Out:
#     Sales  Discount    Profit
# 0  261.96       0.0   41.9136
# 1  731.94       0.0  219.5820

# %%
df.select_dtypes(include=['int64']).shape
# Out:
# (9994, 3)

# %%
df.select_dtypes(include=['object']).shape
# Out:
# (9994, 15)

# %%
df.select_dtypes(include=['float64']).shape
# Out:
# (9994, 3)

# %%
df.shape
# Out:
# (9994, 21)

# %%
df1=df.iloc[0:6,0:7].copy()
df1
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   8/11/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   8/11/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   12/6/2016   16/6/2016    Second Class    DV-13045
# 3       4  US-2015-108966  11/10/2015  18/10/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  11/10/2015  18/10/2015  Standard Class    SO-20335
# 5       6  CA-2014-115812    9/6/2014   14/6/2014  Standard Class    BH-11710
#
#      Customer Name
# 0      Claire Gute
# 1      Claire Gute
# 2  Darrin Van Huff
# 3   Sean O'Donnell
# 4   Sean O'Donnell
# 5  Brosina Hoffman

# %%
df1.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name'],
#       dtype='object')

# %%
df['Row ID'].min()
# Out:
# 1

# %%
df[['Sales','Row ID']].min()
# Out:
# Sales     0.444
# Row ID    1.000
# dtype: float64

# %%
df[['Sales']].mean()
# Out:
# Sales    229.858001
# dtype: float64

# %%
df['Customer Name'].str.upper().head(3)
# Out:
# 0        CLAIRE GUTE
# 1        CLAIRE GUTE
# 2    DARRIN VAN HUFF
# Name: Customer Name, dtype: object

# %%
df['Customer Name'].str.split('a').head(3)
# Out:
# 0         [Cl, ire Gute]
# 1         [Cl, ire Gute]
# 2    [D, rrin V, n Huff]
# Name: Customer Name, dtype: object

# %%
df1['Order ID'].str.pad(width=67,side='right',fillchar=":")
# Out:
# 0    CA-2016-152156::::::::::::::::::::::::::::::::...
# 1    CA-2016-152156::::::::::::::::::::::::::::::::...
# 2    CA-2016-138688::::::::::::::::::::::::::::::::...
# 3    US-2015-108966::::::::::::::::::::::::::::::::...
# 4    US-2015-108966::::::::::::::::::::::::::::::::...
# 5    CA-2014-115812::::::::::::::::::::::::::::::::...
# Name: Order ID, dtype: object
