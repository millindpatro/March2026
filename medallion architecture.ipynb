# %%
from pyspark.sql.types import *
# SalesLT Address
address_schema = StructType([
    StructField("AddressID", IntegerType(), False),
    StructField("AddressLine1", StringType(), False),
    StructField("AddressLine2", StringType(), True),
    StructField("City", StringType(), False),
    StructField("StateProvince", StringType(), False),
    StructField("CountryRegion", StringType(), False),
    StructField("PostalCode", StringType(), False),
    StructField("rowguid", StringType(), False),
    StructField("ModifiedDate", TimestampType(), False)
])

# SalesLT Customer
customer_schema = StructType([
    StructField("CustomerID", IntegerType(), False),
    StructField("NameStyle", BooleanType(), False),
    StructField("Title", StringType(), True),
    StructField("FirstName", StringType(), False),
    StructField("MiddleName", StringType(), True),
    StructField("LastName", StringType(), False),
    StructField("Suffix", StringType(), True),
    StructField("CompanyName", StringType(), True),
    StructField("SalesPerson", StringType(), True),
    StructField("EmailAddress", StringType(), True),
    StructField("Phone", StringType(), True),
    StructField("PasswordHash", StringType(), False),
    StructField("PasswordSalt", StringType(), False),
    StructField("rowguid", StringType(), False),
    StructField("ModifiedDate", TimestampType(), False)
])

# SalesLT CustomerAddress
customer_address_schema = StructType([
    StructField("CustomerID", IntegerType(), False),
    StructField("AddressID", IntegerType(), False),
    StructField("AddressType", StringType(), False),
    StructField("rowguid", StringType(), False),
    StructField("ModifiedDate", TimestampType(), False)
])

# SalesLT Product
product_schema = StructType([
    StructField("ProductID", IntegerType(), False),
    StructField("Name", StringType(), False),
    StructField("ProductNumber", StringType(), False),
    StructField("Color", StringType(), True),
    StructField("StandardCost", DecimalType(19, 4), False),
    StructField("ListPrice", DecimalType(19, 4), False),
    StructField("Size", StringType(), True),
    StructField("Weight", DecimalType(8, 2), True),
    StructField("ProductCategoryID", IntegerType(), True),
    StructField("ProductModelID", IntegerType(), True),
    StructField("SellStartDate", TimestampType(), False),
    StructField("SellEndDate", TimestampType(), True),
    StructField("DiscontinuedDate", TimestampType(), True),
    StructField("ThumbNailPhoto", BinaryType(), True),
    StructField("ThumbnailPhotoFileName", StringType(), True),
    StructField("rowguid", StringType(), False),
    StructField("ModifiedDate", TimestampType(), False)
])

# SalesLT ProductCategory
product_category_schema = StructType([
    StructField("ProductCategoryID", IntegerType(), False),
    StructField("ParentProductCategoryID", IntegerType(), True),
    StructField("Name", StringType(), False),
    StructField("rowguid", StringType(), False),
    StructField("ModifiedDate", TimestampType(), False)
])

# SalesLT ProductDescription
product_description_schema = StructType([
    StructField("ProductDescriptionID", IntegerType(), False),
    StructField("Description", StringType(), False),
    StructField("rowguid", StringType(), False),
    StructField("ModifiedDate", TimestampType(), False)
])

# SalesLT ProductModel
product_model_schema = StructType([
    StructField("ProductModelID", IntegerType(), False),
    StructField("Name", StringType(), False),
    StructField("CatalogDescription", StringType(), True),
    StructField("rowguid", StringType(), False),
    StructField("ModifiedDate", TimestampType(), False)
])

# SalesLT ProductModelProductDescription
product_model_description_schema = StructType([
    StructField("ProductModelID", IntegerType(), False),
    StructField("ProductDescriptionID", IntegerType(), False),
    StructField("Culture", StringType(), False),
    StructField("rowguid", StringType(), False),
    StructField("ModifiedDate", TimestampType(), False)
])

# SalesLT SalesOrderHeader
sales_order_header_schema = StructType([
    StructField("SalesOrderID", IntegerType(), False),
    StructField("RevisionNumber", ByteType(), False),
    StructField("OrderDate", TimestampType(), False),
    StructField("DueDate", TimestampType(), False),
    StructField("ShipDate", TimestampType(), True),
    StructField("Status", ByteType(), False),
    StructField("OnlineOrderFlag", BooleanType(), False),
    StructField("SalesOrderNumber", StringType(), False),
    StructField("PurchaseOrderNumber", StringType(), True),
    StructField("AccountNumber", StringType(), True),
    StructField("CustomerID", IntegerType(), False),
    StructField("ShipToAddressID", IntegerType(), True),
    StructField("BillToAddressID", IntegerType(), True),
    StructField("ShipMethod", StringType(), False),
    StructField("CreditCardApprovalCode", StringType(), True),
    StructField("SubTotal", DecimalType(19, 4), False),
    StructField("TaxAmt", DecimalType(19, 4), False),
    StructField("Freight", DecimalType(19, 4), False),
    StructField("TotalDue", DecimalType(19, 4), False),
    StructField("Comment", StringType(), True),
    StructField("rowguid", StringType(), False),
    StructField("ModifiedDate", TimestampType(), False)
])

# SalesLT SalesOrderDetail
sales_order_detail_schema = StructType([
    StructField("SalesOrderID", IntegerType(), False),
    StructField("SalesOrderDetailID", IntegerType(), False),
    StructField("OrderQty", ShortType(), False),
    StructField("ProductID", IntegerType(), False),
    StructField("UnitPrice", DecimalType(19, 4), False),
    StructField("UnitPriceDiscount", DecimalType(19, 4), False),
    StructField("LineTotal", DecimalType(38, 6), False),
    StructField("rowguid", StringType(), False),
    StructField("ModifiedDate", TimestampType(), False)
])

# Create empty DataFrames
df_address = spark.createDataFrame([], address_schema)
df_customer = spark.createDataFrame([], customer_schema)
df_customer_address = spark.createDataFrame([], customer_address_schema)
df_product = spark.createDataFrame([], product_schema)
df_product_category = spark.createDataFrame([], product_category_schema)
df_product_description = spark.createDataFrame([], product_description_schema)
df_product_model = spark.createDataFrame([], product_model_schema)
df_product_model_description = spark.createDataFrame([], product_model_description_schema)
df_sales_order_header = spark.createDataFrame([], sales_order_header_schema)
df_sales_order_detail = spark.createDataFrame([], sales_order_detail_schema)

# Display schemas
df_address.printSchema()
df_customer.printSchema()
df_customer_address.printSchema()
df_product.printSchema()
df_product_category.printSchema()
df_product_description.printSchema()
df_product_model.printSchema()
df_product_model_description.printSchema()
df_sales_order_header.printSchema()
df_sales_order_detail.printSchema()
# Out:
# root
#  |-- AddressID: integer (nullable = false)
#  |-- AddressLine1: string (nullable = false)
#  |-- AddressLine2: string (nullable = true)
#  |-- City: string (nullable = false)
#  |-- StateProvince: string (nullable = false)
#  |-- CountryRegion: string (nullable = false)
#  |-- PostalCode: string (nullable = false)
#  |-- rowguid: string (nullable = false)
#  |-- ModifiedDate: timestamp (nullable = false)
#
# root
#  |-- CustomerID: integer (nullable = false)
#  |-- NameStyle: boolean (nullable = false)
#  |-- Title: string (nullable = true)
#  |-- FirstName: string (nullable = false)
#  |-- MiddleName: string (nullable = true)
#  |-- LastName: string (nullable = false)
#  |-- Suffix: string (nullable = true)
#  |-- CompanyName: string (nullable = true)
#  |-- SalesPerson: string (nullable = true)
#  |-- EmailAddress: string (nullable = true)
#  |-- Phone: string (nullable = true)
#  |-- PasswordHash: string (nullable = false)
#  |-- PasswordSalt: string (nullable = false)
#  |-- rowguid: string (nullable = false)
#  |-- ModifiedDate: timestamp (nullable = false)
#
# root
#  |-- CustomerID: integer (nullable = false)
#  |-- AddressID: integer (nullable = false)
#  |-- AddressType: string (nullable = false)
#  |-- rowguid: string (nullable = false)
#  |-- ModifiedDate: timestamp (nullable = false)
#
# root
#  |-- ProductID: integer (nullable = false)
#  |-- Name: string (nullable = false)
#  |-- ProductNumber: string (nullable = false)
#  |-- Color: string (nullable = true)
#  |-- StandardCost: decimal(19,4) (nullable = false)
#  |-- ListPrice: decimal(19,4) (nullable = false)
#  |-- Size: string (nullable = true)
#  |-- Weight: decimal(8,2) (nullable = true)
#  |-- ProductCategoryID: integer (nullable = true)
#  |-- ProductModelID: integer (nullable = true)
#  |-- SellStartDate: timestamp (nullable = false)
#  |-- SellEndDate: timestamp (nullable = true)
#  |-- DiscontinuedDate: timestamp (nullable = true)
#  |-- ThumbNailPhoto: binary (nullable = true)
#  |-- ThumbnailPhotoFileName: string (nullable = true)
#  |-- rowguid: string (nullable = false)
#  |-- ModifiedDate: timestamp (nullable = false)
#
# root
#  |-- ProductCategoryID: integer (nullable = false)
#  |-- ParentProductCategoryID: integer (nullable = true)
#  |-- Name: string (nullable = false)
#  |-- rowguid: string (nullable = false)
#  |-- ModifiedDate: timestamp (nullable = false)
#
# root
#  |-- ProductDescriptionID: integer (nullable = false)
#  |-- Description: string (nullable = false)
#  |-- rowguid: string (nullable = false)
#  |-- ModifiedDate: timestamp (nullable = false)
#
# root
#  |-- ProductModelID: integer (nullable = false)
#  |-- Name: string (nullable = false)
#  |-- CatalogDescription: string (nullable = true)
#  |-- rowguid: string (nullable = false)
#  |-- ModifiedDate: timestamp (nullable = false)
#
# root
#  |-- ProductModelID: integer (nullable = false)
#  |-- ProductDescriptionID: integer (nullable = false)
#  |-- Culture: string (nullable = false)
#  |-- rowguid: string (nullable = false)
#  |-- ModifiedDate: timestamp (nullable = false)
#
# root
#  |-- SalesOrderID: integer (nullable = false)
#  |-- RevisionNumber: byte (nullable = false)
#  |-- OrderDate: timestamp (nullable = false)
#  |-- DueDate: timestamp (nullable = false)
#  |-- ShipDate: timestamp (nullable = true)
#  |-- Status: byte (nullable = false)
#  |-- OnlineOrderFlag: boolean (nullable = false)
#  |-- SalesOrderNumber: string (nullable = false)
#  |-- PurchaseOrderNumber: string (nullable = true)
#  |-- AccountNumber: string (nullable = true)
#  |-- CustomerID: integer (nullable = false)
#  |-- ShipToAddressID: integer (nullable = true)
#  |-- BillToAddressID: integer (nullable = true)
#  |-- ShipMethod: string (nullable = false)
#  |-- CreditCardApprovalCode: string (nullable = true)
#  |-- SubTotal: decimal(19,4) (nullable = false)
#  |-- TaxAmt: decimal(19,4) (nullable = false)
#  |-- Freight: decimal(19,4) (nullable = false)
#  |-- TotalDue: decimal(19,4) (nullable = false)
#  |-- Comment: string (nullable = true)
#  |-- rowguid: string (nullable = false)
#  |-- ModifiedDate: timestamp (nullable = false)
#
# root
#  |-- SalesOrderID: integer (nullable = false)
#  |-- SalesOrderDetailID: integer (nullable = false)
#  |-- OrderQty: short (nullable = false)
#  |-- ProductID: integer (nullable = false)
#  |-- UnitPrice: decimal(19,4) (nullable = false)
#  |-- UnitPriceDiscount: decimal(19,4) (nullable = false)
#  |-- LineTotal: decimal(38,6) (nullable = false)
#  |-- rowguid: string (nullable = false)
#  |-- ModifiedDate: timestamp (nullable = false)

# %%
from pyspark.sql.types import *
from decimal import Decimal
from datetime import datetime

# -------------------------------
# 1. Address
# -------------------------------
address_schema = StructType([
    StructField("AddressID", IntegerType(), False),
    StructField("AddressLine1", StringType(), False),
    StructField("AddressLine2", StringType(), True),
    StructField("City", StringType(), False),
    StructField("StateProvince", StringType(), False),
    StructField("CountryRegion", StringType(), False),
    StructField("PostalCode", StringType(), False),
    StructField("rowguid", StringType(), False),
    StructField("ModifiedDate", TimestampType(), False)
])

address_data = [
    (1, "1970 Napa Ct.", None, "Bothell", "Washington", "United States", "98011", "A1", datetime(2026,1,1)),
    (2, "9833 Mt. Dias Blv.", None, "Dallas", "Texas", "United States", "75201", "A2", datetime(2026,1,2)),
    (3, "7484 Roundtree Drive", None, "Toronto", "Ontario", "Canada", "M4B 1B3", "A3", datetime(2026,1,3)),
    (4, "9539 Glenside Dr", None, "London", "England", "United Kingdom", "EC1A 1BB", "A4", datetime(2026,1,4)),
    (5, "1226 Shoe St.", None, "Bangalore", "Karnataka", "India", "560001", "A5", datetime(2026,1,5))
]

df_address = spark.createDataFrame(address_data, address_schema)

# -------------------------------
# 2. Customer
# -------------------------------
customer_schema = StructType([
    StructField("CustomerID", IntegerType(), False),
    StructField("NameStyle", BooleanType(), False),
    StructField("Title", StringType(), True),
    StructField("FirstName", StringType(), False),
    StructField("MiddleName", StringType(), True),
    StructField("LastName", StringType(), False),
    StructField("Suffix", StringType(), True),
    StructField("CompanyName", StringType(), True),
    StructField("SalesPerson", StringType(), True),
    StructField("EmailAddress", StringType(), True),
    StructField("Phone", StringType(), True),
    StructField("PasswordHash", StringType(), False),
    StructField("PasswordSalt", StringType(), False),
    StructField("rowguid", StringType(), False),
    StructField("ModifiedDate", TimestampType(), False)
])

customer_data = [
    (1, False, "Mr.", "Orlando", "N.", "Gee", None, "A Bike Store", "adventure-works\\pamela0", "orlando@example.com", "245-555-0173", "hash1", "salt1", "C1", datetime(2026,1,1)),
    (2, False, "Mr.", "Keith", None, "Harris", None, "Progressive Sports", "adventure-works\\david8", "keith@example.com", "170-555-0127", "hash2", "salt2", "C2", datetime(2026,1,2)),
    (3, False, "Ms.", "Donna", "F.", "Carreras", None, "Advanced Bike Components", "adventure-works\\jillian0", "donna@example.com", "279-555-0130", "hash3", "salt3", "C3", datetime(2026,1,3)),
    (4, False, "Mr.", "Janeth", None, "Esteves", None, "Modular Cycle Systems", "adventure-works\\garrett1", "janeth@example.com", "710-555-0173", "hash4", "salt4", "C4", datetime(2026,1,4)),
    (5, False, "Ms.", "Lucy", None, "Harrington", None, "Metropolitan Sports", "adventure-works\\jillian0", "lucy@example.com", "828-555-0188", "hash5", "salt5", "C5", datetime(2026,1,5))
]

df_customer = spark.createDataFrame(customer_data, customer_schema)

# -------------------------------
# 3. CustomerAddress
# -------------------------------
customer_address_schema = StructType([
    StructField("CustomerID", IntegerType(), False),
    StructField("AddressID", IntegerType(), False),
    StructField("AddressType", StringType(), False),
    StructField("rowguid", StringType(), False),
    StructField("ModifiedDate", TimestampType(), False)
])

customer_address_data = [
    (1, 1, "Main Office", "CA1", datetime(2026,1,1)),
    (2, 2, "Shipping", "CA2", datetime(2026,1,2)),
    (3, 3, "Billing", "CA3", datetime(2026,1,3)),
    (4, 4, "Main Office", "CA4", datetime(2026,1,4)),
    (5, 5, "Shipping", "CA5", datetime(2026,1,5))
]

df_customer_address = spark.createDataFrame(customer_address_data, customer_address_schema)

# -------------------------------
# 4. ProductCategory
# -------------------------------
product_category_schema = StructType([
    StructField("ProductCategoryID", IntegerType(), False),
    StructField("ParentProductCategoryID", IntegerType(), True),
    StructField("Name", StringType(), False),
    StructField("rowguid", StringType(), False),
    StructField("ModifiedDate", TimestampType(), False)
])

product_category_data = [
    (1, None, "Bikes", "PC1", datetime(2026,1,1)),
    (2, None, "Components", "PC2", datetime(2026,1,2)),
    (3, None, "Clothing", "PC3", datetime(2026,1,3)),
    (4, None, "Accessories", "PC4", datetime(2026,1,4)),
    (5, 1, "Mountain Bikes", "PC5", datetime(2026,1,5))
]

df_product_category = spark.createDataFrame(product_category_data, product_category_schema)

# -------------------------------
# 5. ProductModel
# -------------------------------
product_model_schema = StructType([
    StructField("ProductModelID", IntegerType(), False),
    StructField("Name", StringType(), False),
    StructField("CatalogDescription", StringType(), True),
    StructField("rowguid", StringType(), False),
    StructField("ModifiedDate", TimestampType(), False)
])

product_model_data = [
    (1, "Classic Vest", "Lightweight vest model", "PM1", datetime(2026,1,1)),
    (2, "Mountain-100", "High performance mountain bike", "PM2", datetime(2026,1,2)),
    (3, "Road-150", "Road racing bike", "PM3", datetime(2026,1,3)),
    (4, "Touring-2000", "Touring bike model", "PM4", datetime(2026,1,4)),
    (5, "Sport Helmet", "Helmet model", "PM5", datetime(2026,1,5))
]

df_product_model = spark.createDataFrame(product_model_data, product_model_schema)

# -------------------------------
# 6. Product
# -------------------------------
product_schema = StructType([
    StructField("ProductID", IntegerType(), False),
    StructField("Name", StringType(), False),
    StructField("ProductNumber", StringType(), False),
    StructField("Color", StringType(), True),
    StructField("StandardCost", DecimalType(19,4), False),
    StructField("ListPrice", DecimalType(19,4), False),
    StructField("Size", StringType(), True),
    StructField("Weight", DecimalType(8,2), True),
    StructField("ProductCategoryID", IntegerType(), True),
    StructField("ProductModelID", IntegerType(), True),
    StructField("SellStartDate", TimestampType(), False),
    StructField("SellEndDate", TimestampType(), True),
    StructField("DiscontinuedDate", TimestampType(), True),
    StructField("ThumbNailPhoto", BinaryType(), True),
    StructField("ThumbnailPhotoFileName", StringType(), True),
    StructField("rowguid", StringType(), False),
    StructField("ModifiedDate", TimestampType(), False)
])

product_data = [
    (1, "Mountain Bike", "BK-M68", "Black", Decimal("1200.00"), Decimal("2500.00"), "M", Decimal("15.50"), 5, 2, datetime(2026,1,1), None, None, None, "mountain.jpg", "P1", datetime(2026,1,1)),
    (2, "Road Bike", "BK-R79", "Red", Decimal("1500.00"), Decimal("3200.00"), "L", Decimal("12.80"), 1, 3, datetime(2026,1,2), None, None, None, "road.jpg", "P2", datetime(2026,1,2)),
    (3, "Touring Bike", "BK-T44", "Blue", Decimal("1000.00"), Decimal("2100.00"), "M", Decimal("14.20"), 1, 4, datetime(2026,1,3), None, None, None, "touring.jpg", "P3", datetime(2026,1,3)),
    (4, "Sport Helmet", "HL-U509", "Yellow", Decimal("20.00"), Decimal("49.99"), None, Decimal("1.20"), 4, 5, datetime(2026,1,4), None, None, None, "helmet.jpg", "P4", datetime(2026,1,4)),
    (5, "Classic Vest", "VE-C304", "Blue", Decimal("30.00"), Decimal("63.50"), "L", Decimal("0.80"), 3, 1, datetime(2026,1,5), None, None, None, "vest.jpg", "P5", datetime(2026,1,5))
]

df_product = spark.createDataFrame(product_data, product_schema)

# -------------------------------
# 7. ProductDescription
# -------------------------------
product_description_schema = StructType([
    StructField("ProductDescriptionID", IntegerType(), False),
    StructField("Description", StringType(), False),
    StructField("rowguid", StringType(), False),
    StructField("ModifiedDate", TimestampType(), False)
])

product_description_data = [
    (1, "High quality mountain bike for rough roads", "PD1", datetime(2026,1,1)),
    (2, "Fast road bike for racing", "PD2", datetime(2026,1,2)),
    (3, "Comfortable touring bike", "PD3", datetime(2026,1,3)),
    (4, "Durable sport helmet", "PD4", datetime(2026,1,4)),
    (5, "Classic blue cycling vest", "PD5", datetime(2026,1,5))
]

df_product_description = spark.createDataFrame(product_description_data, product_description_schema)

# -------------------------------
# 8. ProductModelProductDescription
# -------------------------------
product_model_description_schema = StructType([
    StructField("ProductModelID", IntegerType(), False),
    StructField("ProductDescriptionID", IntegerType(), False),
    StructField("Culture", StringType(), False),
    StructField("rowguid", StringType(), False),
    StructField("ModifiedDate", TimestampType(), False)
])

product_model_description_data = [
    (2, 1, "en", "PMPD1", datetime(2026,1,1)),
    (3, 2, "en", "PMPD2", datetime(2026,1,2)),
    (4, 3, "en", "PMPD3", datetime(2026,1,3)),
    (5, 4, "en", "PMPD4", datetime(2026,1,4)),
    (1, 5, "en", "PMPD5", datetime(2026,1,5))
]

df_product_model_description = spark.createDataFrame(product_model_description_data, product_model_description_schema)

# -------------------------------
# 9. SalesOrderHeader
# -------------------------------
sales_order_header_schema = StructType([
    StructField("SalesOrderID", IntegerType(), False),
    StructField("RevisionNumber", ByteType(), False),
    StructField("OrderDate", TimestampType(), False),
    StructField("DueDate", TimestampType(), False),
    StructField("ShipDate", TimestampType(), True),
    StructField("Status", ByteType(), False),
    StructField("OnlineOrderFlag", BooleanType(), False),
    StructField("SalesOrderNumber", StringType(), False),
    StructField("PurchaseOrderNumber", StringType(), True),
    StructField("AccountNumber", StringType(), True),
    StructField("CustomerID", IntegerType(), False),
    StructField("ShipToAddressID", IntegerType(), True),
    StructField("BillToAddressID", IntegerType(), True),
    StructField("ShipMethod", StringType(), False),
    StructField("CreditCardApprovalCode", StringType(), True),
    StructField("SubTotal", DecimalType(19,4), False),
    StructField("TaxAmt", DecimalType(19,4), False),
    StructField("Freight", DecimalType(19,4), False),
    StructField("TotalDue", DecimalType(19,4), False),
    StructField("Comment", StringType(), True),
    StructField("rowguid", StringType(), False),
    StructField("ModifiedDate", TimestampType(), False)
])

sales_order_header_data = [
    (1001, 1, datetime(2026,2,1), datetime(2026,2,10), datetime(2026,2,5), 5, True, "SO1001", "PO1001", "10-4020-000001", 1, 1, 1, "CARGO TRANSPORT 5", "APPROVED", Decimal("2500.00"), Decimal("200.00"), Decimal("50.00"), Decimal("2750.00"), None, "SOH1", datetime(2026,2,1)),
    (1002, 1, datetime(2026,2,2), datetime(2026,2,11), datetime(2026,2,6), 5, True, "SO1002", "PO1002", "10-4020-000002", 2, 2, 2, "CARGO TRANSPORT 5", "APPROVED", Decimal("3200.00"), Decimal("256.00"), Decimal("70.00"), Decimal("3526.00"), None, "SOH2", datetime(2026,2,2)),
    (1003, 1, datetime(2026,2,3), datetime(2026,2,12), datetime(2026,2,7), 5, False, "SO1003", "PO1003", "10-4020-000003", 3, 3, 3, "CARGO TRANSPORT 5", "APPROVED", Decimal("2100.00"), Decimal("168.00"), Decimal("60.00"), Decimal("2328.00"), None, "SOH3", datetime(2026,2,3))
]

df_sales_order_header = spark.createDataFrame(sales_order_header_data, sales_order_header_schema)

# -------------------------------
# 10. SalesOrderDetail
# -------------------------------
sales_order_detail_schema = StructType([
    StructField("SalesOrderID", IntegerType(), False),
    StructField("SalesOrderDetailID", IntegerType(), False),
    StructField("OrderQty", ShortType(), False),
    StructField("ProductID", IntegerType(), False),
    StructField("UnitPrice", DecimalType(19,4), False),
    StructField("UnitPriceDiscount", DecimalType(19,4), False),
    StructField("LineTotal", DecimalType(38,6), False),
    StructField("rowguid", StringType(), False),
    StructField("ModifiedDate", TimestampType(), False)
])

sales_order_detail_data = [
    (1001, 1, 1, 1, Decimal("2500.00"), Decimal("0.00"), Decimal("2500.000000"), "SOD1", datetime(2026,2,1)),
    (1002, 2, 1, 2, Decimal("3200.00"), Decimal("0.00"), Decimal("3200.000000"), "SOD2", datetime(2026,2,2)),
    (1003, 3, 1, 3, Decimal("2100.00"), Decimal("0.00"), Decimal("2100.000000"), "SOD3", datetime(2026,2,3)),
    (1001, 4, 2, 4, Decimal("49.99"), Decimal("0.00"), Decimal("99.980000"), "SOD4", datetime(2026,2,1)),
    (1002, 5, 3, 5, Decimal("63.50"), Decimal("0.00"), Decimal("190.500000"), "SOD5", datetime(2026,2,2))
]

df_sales_order_detail = spark.createDataFrame(sales_order_detail_data, sales_order_detail_schema)

# -------------------------------
# Display all tables
# -------------------------------
df_address.show(truncate=False)
df_customer.show(truncate=False)
df_customer_address.show(truncate=False)
df_product_category.show(truncate=False)
df_product_model.show(truncate=False)
df_product.show(truncate=False)
df_product_description.show(truncate=False)
df_product_model_description.show(truncate=False)
df_sales_order_header.show(truncate=False)
df_sales_order_detail.show(truncate=False)
# Out:
# +---------+--------------------+------------+---------+-------------+--------------+----------+-------+-------------------+
# |AddressID|AddressLine1        |AddressLine2|City     |StateProvince|CountryRegion |PostalCode|rowguid|ModifiedDate       |
# +---------+--------------------+------------+---------+-------------+--------------+----------+-------+-------------------+
# |1        |1970 Napa Ct.       |NULL        |Bothell  |Washington   |United States |98011     |A1     |2026-01-01 00:00:00|
# |2        |9833 Mt. Dias Blv.  |NULL        |Dallas   |Texas        |United States |75201     |A2     |2026-01-02 00:00:00|
# |3        |7484 Roundtree Drive|NULL        |Toronto  |Ontario      |Canada        |M4B 1B3   |A3     |2026-01-03 00:00:00|
# |4        |9539 Glenside Dr    |NULL        |London   |England      |United Kingdom|EC1A 1BB  |A4     |2026-01-04 00:00:00|
# |5        |1226 Shoe St.       |NULL        |Bangalore|Karnataka    |India         |560001    |A5     |2026-01-05 00:00:00|
# +---------+--------------------+------------+---------+-------------+--------------+----------+-------+-------------------+
#
# +----------+---------+-----+---------+----------+----------+------+------------------------+------------------------+-------------------+------------+------------+------------+-------+-------------------+
# |CustomerID|NameStyle|Title|FirstName|MiddleName|LastName  |Suffix|CompanyName             |SalesPerson             |EmailAddress       |Phone       |PasswordHash|PasswordSalt|rowguid|ModifiedDate       |
# +----------+---------+-----+---------+----------+----------+------+------------------------+------------------------+-------------------+------------+------------+------------+-------+-------------------+
# |1         |false    |Mr.  |Orlando  |N.        |Gee       |NULL  |A Bike Store            |adventure-works\pamela0 |orlando@example.com|245-555-0173|hash1       |salt1       |C1     |2026-01-01 00:00:00|
# |2         |false    |Mr.  |Keith    |NULL      |Harris    |NULL  |Progressive Sports      |adventure-works\david8  |keith@example.com  |170-555-0127|hash2       |salt2       |C2     |2026-01-02 00:00:00|
# |3         |false    |Ms.  |Donna    |F.        |Carreras  |NULL  |Advanced Bike Components|adventure-works\jillian0|donna@example.com  |279-555-0130|hash3       |salt3       |C3     |2026-01-03 00:00:00|
# |4         |false    |Mr.  |Janeth   |NULL      |Esteves   |NULL  |Modular Cycle Systems   |adventure-works\garrett1|janeth@example.com |710-555-0173|hash4       |salt4       |C4     |2026-01-04 00:00:00|
# |5         |false    |Ms.  |Lucy     |NULL      |Harrington|NULL  |Metropolitan Sports     |adventure-works\jillian0|lucy@example.com   |828-555-0188|hash5       |salt5       |C5     |2026-01-05 00:00:00|
# +----------+---------+-----+---------+----------+----------+------+------------------------+------------------------+-------------------+------------+------------+------------+-------+-------------------+
#
# +----------+---------+-----------+-------+-------------------+
# |CustomerID|AddressID|AddressType|rowguid|ModifiedDate       |
# +----------+---------+-----------+-------+-------------------+
# |1         |1        |Main Office|CA1    |2026-01-01 00:00:00|
# |2         |2        |Shipping   |CA2    |2026-01-02 00:00:00|
# |3         |3        |Billing    |CA3    |2026-01-03 00:00:00|
# |4         |4        |Main Office|CA4    |2026-01-04 00:00:00|
# |5         |5        |Shipping   |CA5    |2026-01-05 00:00:00|
# +----------+---------+-----------+-------+-------------------+
#
# +-----------------+-----------------------+--------------+-------+-------------------+
# |ProductCategoryID|ParentProductCategoryID|Name          |rowguid|ModifiedDate       |
# +-----------------+-----------------------+--------------+-------+-------------------+
# |1                |NULL                   |Bikes         |PC1    |2026-01-01 00:00:00|
# |2                |NULL                   |Components    |PC2    |2026-01-02 00:00:00|
# |3                |NULL                   |Clothing      |PC3    |2026-01-03 00:00:00|
# |4                |NULL                   |Accessories   |PC4    |2026-01-04 00:00:00|
# |5                |1                      |Mountain Bikes|PC5    |2026-01-05 00:00:00|
# +-----------------+-----------------------+--------------+-------+-------------------+
#
# +--------------+------------+------------------------------+-------+-------------------+
# |ProductModelID|Name        |CatalogDescription            |rowguid|ModifiedDate       |
# +--------------+------------+------------------------------+-------+-------------------+
# |1             |Classic Vest|Lightweight vest model        |PM1    |2026-01-01 00:00:00|
# |2             |Mountain-100|High performance mountain bike|PM2    |2026-01-02 00:00:00|
# |3             |Road-150    |Road racing bike              |PM3    |2026-01-03 00:00:00|
# |4             |Touring-2000|Touring bike model            |PM4    |2026-01-04 00:00:00|
# |5             |Sport Helmet|Helmet model                  |PM5    |2026-01-05 00:00:00|
# +--------------+------------+------------------------------+-------+-------------------+
#
# +---------+-------------+-------------+------+------------+---------+----+------+-----------------+--------------+-------------------+-----------+----------------+--------------+----------------------+-------+-------------------+
# |ProductID|Name         |ProductNumber|Color |StandardCost|ListPrice|Size|Weight|ProductCategoryID|ProductModelID|SellStartDate      |SellEndDate|DiscontinuedDate|ThumbNailPhoto|ThumbnailPhotoFileName|rowguid|ModifiedDate       |
# +---------+-------------+-------------+------+------------+---------+----+------+-----------------+--------------+-------------------+-----------+----------------+--------------+----------------------+-------+-------------------+
# |1        |Mountain Bike|BK-M68       |Black |1200.0000   |2500.0000|M   |15.50 |5                |2             |2026-01-01 00:00:00|NULL       |NULL            |NULL          |mountain.jpg          |P1     |2026-01-01 00:00:00|
# |2        |Road Bike    |BK-R79       |Red   |1500.0000   |3200.0000|L   |12.80 |1                |3             |2026-01-02 00:00:00|NULL       |NULL            |NULL          |road.jpg              |P2     |2026-01-02 00:00:00|
# |3        |Touring Bike |BK-T44       |Blue  |1000.0000   |2100.0000|M   |14.20 |1                |4             |2026-01-03 00:00:00|NULL       |NULL            |NULL          |touring.jpg           |P3     |2026-01-03 00:00:00|
# |4        |Sport Helmet |HL-U509      |Yellow|20.0000     |49.9900  |NULL|1.20  |4                |5             |2026-01-04 00:00:00|NULL       |NULL            |NULL          |helmet.jpg            |P4     |2026-01-04 00:00:00|
# |5        |Classic Vest |VE-C304      |Blue  |30.0000     |63.5000  |L   |0.80  |3                |1             |2026-01-05 00:00:00|NULL       |NULL            |NULL          |vest.jpg              |P5     |2026-01-05 00:00:00|
# +---------+-------------+-------------+------+------------+---------+----+------+-----------------+--------------+-------------------+-----------+----------------+--------------+----------------------+-------+-------------------+
#
# +--------------------+------------------------------------------+-------+-------------------+
# |ProductDescriptionID|Description                               |rowguid|ModifiedDate       |
# +--------------------+------------------------------------------+-------+-------------------+
# |1                   |High quality mountain bike for rough roads|PD1    |2026-01-01 00:00:00|
# |2                   |Fast road bike for racing                 |PD2    |2026-01-02 00:00:00|
# |3                   |Comfortable touring bike                  |PD3    |2026-01-03 00:00:00|
# |4                   |Durable sport helmet                      |PD4    |2026-01-04 00:00:00|
# |5                   |Classic blue cycling vest                 |PD5    |2026-01-05 00:00:00|
# +--------------------+------------------------------------------+-------+-------------------+
#
# +--------------+--------------------+-------+-------+-------------------+
# |ProductModelID|ProductDescriptionID|Culture|rowguid|ModifiedDate       |
# +--------------+--------------------+-------+-------+-------------------+
# |2             |1                   |en     |PMPD1  |2026-01-01 00:00:00|
# |3             |2                   |en     |PMPD2  |2026-01-02 00:00:00|
# |4             |3                   |en     |PMPD3  |2026-01-03 00:00:00|
# |5             |4                   |en     |PMPD4  |2026-01-04 00:00:00|
# |1             |5                   |en     |PMPD5  |2026-01-05 00:00:00|
# +--------------+--------------------+-------+-------+-------------------+
#
# +------------+--------------+-------------------+-------------------+-------------------+------+---------------+----------------+-------------------+--------------+----------+---------------+---------------+-----------------+----------------------+---------+--------+-------+---------+-------+-------+-------------------+
# |SalesOrderID|RevisionNumber|OrderDate          |DueDate            |ShipDate           |Status|OnlineOrderFlag|SalesOrderNumber|PurchaseOrderNumber|AccountNumber |CustomerID|ShipToAddressID|BillToAddressID|ShipMethod       |CreditCardApprovalCode|SubTotal |TaxAmt  |Freight|TotalDue |Comment|rowguid|ModifiedDate       |
# +------------+--------------+-------------------+-------------------+-------------------+------+---------------+----------------+-------------------+--------------+----------+---------------+---------------+-----------------+----------------------+---------+--------+-------+---------+-------+-------+-------------------+
# |1001        |1             |2026-02-01 00:00:00|2026-02-10 00:00:00|2026-02-05 00:00:00|5     |true           |SO1001          |PO1001             |10-4020-000001|1         |1              |1              |CARGO TRANSPORT 5|APPROVED              |2500.0000|200.0000|50.0000|2750.0000|NULL   |SOH1   |2026-02-01 00:00:00|
# |1002        |1             |2026-02-02 00:00:00|2026-02-11 00:00:00|2026-02-06 00:00:00|5     |true           |SO1002          |PO1002             |10-4020-000002|2         |2              |2              |CARGO TRANSPORT 5|APPROVED              |3200.0000|256.0000|70.0000|3526.0000|NULL   |SOH2   |2026-02-02 00:00:00|
# |1003        |1             |2026-02-03 00:00:00|2026-02-12 00:00:00|2026-02-07 00:00:00|5     |false          |SO1003          |PO1003             |10-4020-000003|3         |3              |3              |CARGO TRANSPORT 5|APPROVED              |2100.0000|168.0000|60.0000|2328.0000|NULL   |SOH3   |2026-02-03 00:00:00|
# +------------+--------------+-------------------+-------------------+-------------------+------+---------------+----------------+-------------------+--------------+----------+---------------+---------------+-----------------+----------------------+---------+--------+-------+---------+-------+-------+-------------------+
#
# +------------+------------------+--------+---------+---------+-----------------+-----------+-------+-------------------+
# |SalesOrderID|SalesOrderDetailID|OrderQty|ProductID|UnitPrice|UnitPriceDiscount|LineTotal  |rowguid|ModifiedDate       |
# +------------+------------------+--------+---------+---------+-----------------+-----------+-------+-------------------+
# |1001        |1                 |1       |1        |2500.0000|0.0000           |2500.000000|SOD1   |2026-02-01 00:00:00|
# |1002        |2                 |1       |2        |3200.0000|0.0000           |3200.000000|SOD2   |2026-02-02 00:00:00|
# |1003        |3                 |1       |3        |2100.0000|0.0000           |2100.000000|SOD3   |2026-02-03 00:00:00|
# |1001        |4                 |2       |4        |49.9900  |0.0000           |99.980000  |SOD4   |2026-02-01 00:00:00|
# |1002        |5                 |3       |5        |63.5000  |0.0000           |190.500000 |SOD5   |2026-02-02 00:00:00|
# +------------+------------------+--------+---------+---------+-----------------+-----------+-------+-------------------+

# %%
saleslt_schemas = {
    "Address": address_schema,
    "Customer": customer_schema,
    "CustomerAddress": customer_address_schema,
    "Product": product_schema,
    "ProductCategory": product_category_schema,
    "ProductDescription": product_description_schema,
    "ProductModel": product_model_schema,
    "ProductModelProductDescription": product_model_description_schema,
    "SalesOrderHeader": sales_order_header_schema,
    "SalesOrderDetail": sales_order_detail_schema
}

# %%
from pyspark.sql.functions import current_timestamp
df_address = df_address.withColumn('ingestion_timestamp', current_timestamp())
df_customer = df_customer.withColumn('ingestion_timestamp', current_timestamp())
df_customer_address = df_customer_address.withColumn('ingestion_timestamp', current_timestamp())
df_product = df_product.withColumn('ingestion_timestamp', current_timestamp())
df_product_category = df_product_category.withColumn('ingestion_timestamp', current_timestamp())
df_product_description = df_product_description.withColumn('ingestion_timestamp', current_timestamp())
df_product_model = df_product_model.withColumn('ingestion_timestamp', current_timestamp())
df_product_model_product_description = df_product_model_description.withColumn('ingestion_timestamp', current_timestamp())
df_sales_order_header = df_sales_order_header.withColumn('ingestion_timestamp', current_timestamp())
df_sales_order_detail = df_sales_order_detail.withColumn('ingestion_timestamp', current_timestamp())

# %%
from pyspark.sql.functions import *

df_address = df_address.withColumn(
    "source_system",
    lit("AzureSQL")
)
df_address.show()
# Out:
# +---------+--------------------+------------+---------+-------------+--------------+----------+-------+-------------------+--------------------+-------------+
# |AddressID|        AddressLine1|AddressLine2|     City|StateProvince| CountryRegion|PostalCode|rowguid|       ModifiedDate| ingestion_timestamp|source_system|
# +---------+--------------------+------------+---------+-------------+--------------+----------+-------+-------------------+--------------------+-------------+
# |        1|       1970 Napa Ct.|        NULL|  Bothell|   Washington| United States|     98011|     A1|2026-01-01 00:00:00|2026-06-11 14:55:...|     AzureSQL|
# |        2|  9833 Mt. Dias Blv.|        NULL|   Dallas|        Texas| United States|     75201|     A2|2026-01-02 00:00:00|2026-06-11 14:55:...|     AzureSQL|
# |        3|7484 Roundtree Drive|        NULL|  Toronto|      Ontario|        Canada|   M4B 1B3|     A3|2026-01-03 00:00:00|2026-06-11 14:55:...|     AzureSQL|
# |        4|    9539 Glenside Dr|        NULL|   London|      England|United Kingdom|  EC1A 1BB|     A4|2026-01-04 00:00:00|2026-06-11 14:55:...|     AzureSQL|
# |        5|       1226 Shoe St.|        NULL|Bangalore|    Karnataka|         India|    560001|     A5|2026-01-05 00:00:00|2026-06-11 14:55:...|     AzureSQL|
# +---------+--------------------+------------+---------+-------------+--------------+----------+-------+-------------------+--------------------+-------------+

# %%
df_address = df_address.withColumn(
    "source_table",
    lit("Address")
)

# %%
df_address.show(10, truncate=False)
df_customer.show(10,truncate=False)
df_customer_address.show(10,truncate=False)
df_product.show(10,truncate=False)
df_product_category.show(10,truncate=False)
df_product_description.show(10,truncate=False)
df_product_model.show(10,truncate=False)
df_product_model_description.show(10,truncate=False)
df_sales_order_header.show(10,truncate=False)
df_sales_order_detail.show(10,truncate=False)
# Out:
# +---------+--------------------+------------+---------+-------------+--------------+----------+-------+-------------------+-------------------------+-------------+------------+
# |AddressID|AddressLine1        |AddressLine2|City     |StateProvince|CountryRegion |PostalCode|rowguid|ModifiedDate       |ingestion_timestamp      |source_system|source_table|
# +---------+--------------------+------------+---------+-------------+--------------+----------+-------+-------------------+-------------------------+-------------+------------+
# |1        |1970 Napa Ct.       |NULL        |Bothell  |Washington   |United States |98011     |A1     |2026-01-01 00:00:00|2026-06-11 14:55:50.41581|AzureSQL     |Address     |
# |2        |9833 Mt. Dias Blv.  |NULL        |Dallas   |Texas        |United States |75201     |A2     |2026-01-02 00:00:00|2026-06-11 14:55:50.41581|AzureSQL     |Address     |
# |3        |7484 Roundtree Drive|NULL        |Toronto  |Ontario      |Canada        |M4B 1B3   |A3     |2026-01-03 00:00:00|2026-06-11 14:55:50.41581|AzureSQL     |Address     |
# |4        |9539 Glenside Dr    |NULL        |London   |England      |United Kingdom|EC1A 1BB  |A4     |2026-01-04 00:00:00|2026-06-11 14:55:50.41581|AzureSQL     |Address     |
# |5        |1226 Shoe St.       |NULL        |Bangalore|Karnataka    |India         |560001    |A5     |2026-01-05 00:00:00|2026-06-11 14:55:50.41581|AzureSQL     |Address     |
# +---------+--------------------+------------+---------+-------------+--------------+----------+-------+-------------------+-------------------------+-------------+------------+
#
# +----------+---------+-----+---------+----------+----------+------+------------------------+------------------------+-------------------+------------+------------+------------+-------+-------------------+--------------------------+
# |CustomerID|NameStyle|Title|FirstName|MiddleName|LastName  |Suffix|CompanyName             |SalesPerson             |EmailAddress       |Phone       |PasswordHash|PasswordSalt|rowguid|ModifiedDate       |ingestion_timestamp       |
# +----------+---------+-----+---------+----------+----------+------+------------------------+------------------------+-------------------+------------+------------+------------+-------+-------------------+--------------------------+
# |1         |false    |Mr.  |Orlando  |N.        |Gee       |NULL  |A Bike Store            |adventure-works\pamela0 |orlando@example.com|245-555-0173|hash1       |salt1       |C1     |2026-01-01 00:00:00|2026-06-11 14:55:50.621644|
# |2         |false    |Mr.  |Keith    |NULL      |Harris    |NULL  |Progressive Sports      |adventure-works\david8  |keith@example.com  |170-555-0127|hash2       |salt2       |C2     |2026-01-02 00:00:00|2026-06-11 14:55:50.621644|
# |3         |false    |Ms.  |Donna    |F.        |Carreras  |NULL  |Advanced Bike Components|adventure-works\jillian0|donna@example.com  |279-555-0130|hash3       |salt3       |C3     |2026-01-03 00:00:00|2026-06-11 14:55:50.621644|
# |4         |false    |Mr.  |Janeth   |NULL      |Esteves   |NULL  |Modular Cycle Systems   |adventure-works\garrett1|janeth@example.com |710-555-0173|hash4       |salt4       |C4     |2026-01-04 00:00:00|2026-06-11 14:55:50.621644|
# |5         |false    |Ms.  |Lucy     |NULL      |Harrington|NULL  |Metropolitan Sports     |adventure-works\jillian0|lucy@example.com   |828-555-0188|hash5       |salt5       |C5     |2026-01-05 00:00:00|2026-06-11 14:55:50.621644|
# +----------+---------+-----+---------+----------+----------+------+------------------------+------------------------+-------------------+------------+------------+------------+-------+-------------------+--------------------------+
#
# +----------+---------+-----------+-------+-------------------+-------------------------+
# |CustomerID|AddressID|AddressType|rowguid|ModifiedDate       |ingestion_timestamp      |
# +----------+---------+-----------+-------+-------------------+-------------------------+
# |1         |1        |Main Office|CA1    |2026-01-01 00:00:00|2026-06-11 14:55:50.79286|
# |2         |2        |Shipping   |CA2    |2026-01-02 00:00:00|2026-06-11 14:55:50.79286|
# |3         |3        |Billing    |CA3    |2026-01-03 00:00:00|2026-06-11 14:55:50.79286|
# |4         |4        |Main Office|CA4    |2026-01-04 00:00:00|2026-06-11 14:55:50.79286|
# |5         |5        |Shipping   |CA5    |2026-01-05 00:00:00|2026-06-11 14:55:50.79286|
# +----------+---------+-----------+-------+-------------------+-------------------------+
#
# +---------+-------------+-------------+------+------------+---------+----+------+-----------------+--------------+-------------------+-----------+----------------+--------------+----------------------+-------+-------------------+--------------------------+
# |ProductID|Name         |ProductNumber|Color |StandardCost|ListPrice|Size|Weight|ProductCategoryID|ProductModelID|SellStartDate      |SellEndDate|DiscontinuedDate|ThumbNailPhoto|ThumbnailPhotoFileName|rowguid|ModifiedDate       |ingestion_timestamp       |
# +---------+-------------+-------------+------+------------+---------+----+------+-----------------+--------------+-------------------+-----------+----------------+--------------+----------------------+-------+-------------------+--------------------------+
# |1        |Mountain Bike|BK-M68       |Black |1200.0000   |2500.0000|M   |15.50 |5                |2             |2026-01-01 00:00:00|NULL       |NULL            |NULL          |mountain.jpg          |P1     |2026-01-01 00:00:00|2026-06-11 14:55:50.956471|
# |2        |Road Bike    |BK-R79       |Red   |1500.0000   |3200.0000|L   |12.80 |1                |3             |2026-01-02 00:00:00|NULL       |NULL            |NULL          |road.jpg              |P2     |2026-01-02 00:00:00|2026-06-11 14:55:50.956471|
# |3        |Touring Bike |BK-T44       |Blue  |1000.0000   |2100.0000|M   |14.20 |1                |4             |2026-01-03 00:00:00|NULL       |NULL            |NULL          |touring.jpg           |P3     |2026-01-03 00:00:00|2026-06-11 14:55:50.956471|
# |4        |Sport Helmet |HL-U509      |Yellow|20.0000     |49.9900  |NULL|1.20  |4                |5             |2026-01-04 00:00:00|NULL       |NULL            |NULL          |helmet.jpg            |P4     |2026-01-04 00:00:00|2026-06-11 14:55:50.956471|
# |5        |Classic Vest |VE-C304      |Blue  |30.0000     |63.5000  |L   |0.80  |3                |1             |2026-01-05 00:00:00|NULL       |NULL            |NULL          |vest.jpg              |P5     |2026-01-05 00:00:00|2026-06-11 14:55:50.956471|
# +---------+-------------+-------------+------+------------+---------+----+------+-----------------+--------------+-------------------+-----------+----------------+--------------+----------------------+-------+-------------------+--------------------------+
#
# +-----------------+-----------------------+--------------+-------+-------------------+--------------------------+
# |ProductCategoryID|ParentProductCategoryID|Name          |rowguid|ModifiedDate       |ingestion_timestamp       |
# +-----------------+-----------------------+--------------+-------+-------------------+--------------------------+
# |1                |NULL                   |Bikes         |PC1    |2026-01-01 00:00:00|2026-06-11 14:55:51.122601|
# |2                |NULL                   |Components    |PC2    |2026-01-02 00:00:00|2026-06-11 14:55:51.122601|
# |3                |NULL                   |Clothing      |PC3    |2026-01-03 00:00:00|2026-06-11 14:55:51.122601|
# |4                |NULL                   |Accessories   |PC4    |2026-01-04 00:00:00|2026-06-11 14:55:51.122601|
# |5                |1                      |Mountain Bikes|PC5    |2026-01-05 00:00:00|2026-06-11 14:55:51.122601|
# +-----------------+-----------------------+--------------+-------+-------------------+--------------------------+
#
# +--------------------+------------------------------------------+-------+-------------------+-------------------------+
# |ProductDescriptionID|Description                               |rowguid|ModifiedDate       |ingestion_timestamp      |
# +--------------------+------------------------------------------+-------+-------------------+-------------------------+
# |1                   |High quality mountain bike for rough roads|PD1    |2026-01-01 00:00:00|2026-06-11 14:55:51.30561|
# |2                   |Fast road bike for racing                 |PD2    |2026-01-02 00:00:00|2026-06-11 14:55:51.30561|
# |3                   |Comfortable touring bike                  |PD3    |2026-01-03 00:00:00|2026-06-11 14:55:51.30561|
# |4                   |Durable sport helmet                      |PD4    |2026-01-04 00:00:00|2026-06-11 14:55:51.30561|
# |5                   |Classic blue cycling vest                 |PD5    |2026-01-05 00:00:00|2026-06-11 14:55:51.30561|
# +--------------------+------------------------------------------+-------+-------------------+-------------------------+
#
# +--------------+------------+------------------------------+-------+-------------------+--------------------------+
# |ProductModelID|Name        |CatalogDescription            |rowguid|ModifiedDate       |ingestion_timestamp       |
# +--------------+------------+------------------------------+-------+-------------------+--------------------------+
# |1             |Classic Vest|Lightweight vest model        |PM1    |2026-01-01 00:00:00|2026-06-11 14:55:51.532105|
# |2             |Mountain-100|High performance mountain bike|PM2    |2026-01-02 00:00:00|2026-06-11 14:55:51.532105|
# |3             |Road-150    |Road racing bike              |PM3    |2026-01-03 00:00:00|2026-06-11 14:55:51.532105|
# |4             |Touring-2000|Touring bike model            |PM4    |2026-01-04 00:00:00|2026-06-11 14:55:51.532105|
# |5             |Sport Helmet|Helmet model                  |PM5    |2026-01-05 00:00:00|2026-06-11 14:55:51.532105|
# +--------------+------------+------------------------------+-------+-------------------+--------------------------+
#
# +--------------+--------------------+-------+-------+-------------------+
# |ProductModelID|ProductDescriptionID|Culture|rowguid|ModifiedDate       |
# +--------------+--------------------+-------+-------+-------------------+
# |2             |1                   |en     |PMPD1  |2026-01-01 00:00:00|
# |3             |2                   |en     |PMPD2  |2026-01-02 00:00:00|
# |4             |3                   |en     |PMPD3  |2026-01-03 00:00:00|
# |5             |4                   |en     |PMPD4  |2026-01-04 00:00:00|
# |1             |5                   |en     |PMPD5  |2026-01-05 00:00:00|
# +--------------+--------------------+-------+-------+-------------------+
#
# +------------+--------------+-------------------+-------------------+-------------------+------+---------------+----------------+-------------------+--------------+----------+---------------+---------------+-----------------+----------------------+---------+--------+-------+---------+-------+-------+-------------------+--------------------------+
# |SalesOrderID|RevisionNumber|OrderDate          |DueDate            |ShipDate           |Status|OnlineOrderFlag|SalesOrderNumber|PurchaseOrderNumber|AccountNumber |CustomerID|ShipToAddressID|BillToAddressID|ShipMethod       |CreditCardApprovalCode|SubTotal |TaxAmt  |Freight|TotalDue |Comment|rowguid|ModifiedDate       |ingestion_timestamp       |
# +------------+--------------+-------------------+-------------------+-------------------+------+---------------+----------------+-------------------+--------------+----------+---------------+---------------+-----------------+----------------------+---------+--------+-------+---------+-------+-------+-------------------+--------------------------+
# |1001        |1             |2026-02-01 00:00:00|2026-02-10 00:00:00|2026-02-05 00:00:00|5     |true           |SO1001          |PO1001             |10-4020-000001|1         |1              |1              |CARGO TRANSPORT 5|APPROVED              |2500.0000|200.0000|50.0000|2750.0000|NULL   |SOH1   |2026-02-01 00:00:00|2026-06-11 14:55:51.971074|
# |1002        |1             |2026-02-02 00:00:00|2026-02-11 00:00:00|2026-02-06 00:00:00|5     |true           |SO1002          |PO1002             |10-4020-000002|2         |2              |2              |CARGO TRANSPORT 5|APPROVED              |3200.0000|256.0000|70.0000|3526.0000|NULL   |SOH2   |2026-02-02 00:00:00|2026-06-11 14:55:51.971074|
# |1003        |1             |2026-02-03 00:00:00|2026-02-12 00:00:00|2026-02-07 00:00:00|5     |false          |SO1003          |PO1003             |10-4020-000003|3         |3              |3              |CARGO TRANSPORT 5|APPROVED              |2100.0000|168.0000|60.0000|2328.0000|NULL   |SOH3   |2026-02-03 00:00:00|2026-06-11 14:55:51.971074|
# +------------+--------------+-------------------+-------------------+-------------------+------+---------------+----------------+-------------------+--------------+----------+---------------+---------------+-----------------+----------------------+---------+--------+-------+---------+-------+-------+-------------------+--------------------------+
#
# +------------+------------------+--------+---------+---------+-----------------+-----------+-------+-------------------+--------------------------+
# |SalesOrderID|SalesOrderDetailID|OrderQty|ProductID|UnitPrice|UnitPriceDiscount|LineTotal  |rowguid|ModifiedDate       |ingestion_timestamp       |
# +------------+------------------+--------+---------+---------+-----------------+-----------+-------+-------------------+--------------------------+
# |1001        |1                 |1       |1        |2500.0000|0.0000           |2500.000000|SOD1   |2026-02-01 00:00:00|2026-06-11 14:55:52.232881|
# |1002        |2                 |1       |2        |3200.0000|0.0000           |3200.000000|SOD2   |2026-02-02 00:00:00|2026-06-11 14:55:52.232881|
# |1003        |3                 |1       |3        |2100.0000|0.0000           |2100.000000|SOD3   |2026-02-03 00:00:00|2026-06-11 14:55:52.232881|
# |1001        |4                 |2       |4        |49.9900  |0.0000           |99.980000  |SOD4   |2026-02-01 00:00:00|2026-06-11 14:55:52.232881|
# |1002        |5                 |3       |5        |63.5000  |0.0000           |190.500000 |SOD5   |2026-02-02 00:00:00|2026-06-11 14:55:52.232881|
# +------------+------------------+--------+---------+---------+-----------------+-----------+-------+-------------------+--------------------------+

# %%
address_count = df_address.count()
print(f"Address Record Count: {address_count}")
customer_count = df_customer.count()
print(f"Customer Record Count: {customer_count}")
customer_address_count = df_customer_address.count()
print(f"Customer Address Record Count: {customer_address_count}")
product_count = df_product.count()
print(f"Product Record Count: {product_count}")
product_category_count = df_product_category.count()
print(f"Product Category Record Count: {product_category_count}")
product_description_count = df_product_description.count()
print(f"Product Description Record Count: {product_description_count}")
product_model_count = df_product_model.count()
print(f"Product Model Record Count: {product_model_count}")
product_model_description_count = df_product_model_description.count()
print(f"Product Model Description Record Count: {product_model_description_count}")
sales_order_header_count = df_sales_order_header.count()
print(f"Sales Order Header Record Count: {sales_order_header_count}")
sales_order_detail_count = df_sales_order_detail.count()
print(f"Sales Order Detail Record Count: {sales_order_detail_count}")
# Out:
# Address Record Count: 5
# Customer Record Count: 5
# Customer Address Record Count: 5
# Product Record Count: 5
# Product Category Record Count: 5
# Product Description Record Count: 5
# Product Model Record Count: 5
# Product Model Description Record Count: 5
# Sales Order Header Record Count: 3
# Sales Order Detail Record Count: 5

# %%
df_address.printSchema()
df_customer.printSchema()
df_customer_address.printSchema()
df_product.printSchema()
df_product_category.printSchema()
df_product_description.printSchema()
df_product_model.printSchema()
df_product_model_description.printSchema()
df_sales_order_header.printSchema()
df_sales_order_detail.printSchema()
# Out:
# root
#  |-- AddressID: integer (nullable = false)
#  |-- AddressLine1: string (nullable = false)
#  |-- AddressLine2: string (nullable = true)
#  |-- City: string (nullable = false)
#  |-- StateProvince: string (nullable = false)
#  |-- CountryRegion: string (nullable = false)
#  |-- PostalCode: string (nullable = false)
#  |-- rowguid: string (nullable = false)
#  |-- ModifiedDate: timestamp (nullable = false)
#  |-- ingestion_timestamp: timestamp (nullable = false)
#  |-- source_system: string (nullable = false)
#  |-- source_table: string (nullable = false)
#
# root
#  |-- CustomerID: integer (nullable = false)
#  |-- NameStyle: boolean (nullable = false)
#  |-- Title: string (nullable = true)
#  |-- FirstName: string (nullable = false)
#  |-- MiddleName: string (nullable = true)
#  |-- LastName: string (nullable = false)
#  |-- Suffix: string (nullable = true)
#  |-- CompanyName: string (nullable = true)
#  |-- SalesPerson: string (nullable = true)
#  |-- EmailAddress: string (nullable = true)
#  |-- Phone: string (nullable = true)
#  |-- PasswordHash: string (nullable = false)
#  |-- PasswordSalt: string (nullable = false)
#  |-- rowguid: string (nullable = false)
#  |-- ModifiedDate: timestamp (nullable = false)
#  |-- ingestion_timestamp: timestamp (nullable = false)
#
# root
#  |-- CustomerID: integer (nullable = false)
#  |-- AddressID: integer (nullable = false)
#  |-- AddressType: string (nullable = false)
#  |-- rowguid: string (nullable = false)
#  |-- ModifiedDate: timestamp (nullable = false)
#  |-- ingestion_timestamp: timestamp (nullable = false)
#
# root
#  |-- ProductID: integer (nullable = false)
#  |-- Name: string (nullable = false)
#  |-- ProductNumber: string (nullable = false)
#  |-- Color: string (nullable = true)
#  |-- StandardCost: decimal(19,4) (nullable = false)
#  |-- ListPrice: decimal(19,4) (nullable = false)
#  |-- Size: string (nullable = true)
#  |-- Weight: decimal(8,2) (nullable = true)
#  |-- ProductCategoryID: integer (nullable = true)
#  |-- ProductModelID: integer (nullable = true)
#  |-- SellStartDate: timestamp (nullable = false)
#  |-- SellEndDate: timestamp (nullable = true)
#  |-- DiscontinuedDate: timestamp (nullable = true)
#  |-- ThumbNailPhoto: binary (nullable = true)
#  |-- ThumbnailPhotoFileName: string (nullable = true)
#  |-- rowguid: string (nullable = false)
#  |-- ModifiedDate: timestamp (nullable = false)
#  |-- ingestion_timestamp: timestamp (nullable = false)
#
# root
#  |-- ProductCategoryID: integer (nullable = false)
#  |-- ParentProductCategoryID: integer (nullable = true)
#  |-- Name: string (nullable = false)
#  |-- rowguid: string (nullable = false)
#  |-- ModifiedDate: timestamp (nullable = false)
#  |-- ingestion_timestamp: timestamp (nullable = false)
#
# root
#  |-- ProductDescriptionID: integer (nullable = false)
#  |-- Description: string (nullable = false)
#  |-- rowguid: string (nullable = false)
#  |-- ModifiedDate: timestamp (nullable = false)
#  |-- ingestion_timestamp: timestamp (nullable = false)
#
# root
#  |-- ProductModelID: integer (nullable = false)
#  |-- Name: string (nullable = false)
#  |-- CatalogDescription: string (nullable = true)
#  |-- rowguid: string (nullable = false)
#  |-- ModifiedDate: timestamp (nullable = false)
#  |-- ingestion_timestamp: timestamp (nullable = false)
#
# root
#  |-- ProductModelID: integer (nullable = false)
#  |-- ProductDescriptionID: integer (nullable = false)
#  |-- Culture: string (nullable = false)
#  |-- rowguid: string (nullable = false)
#  |-- ModifiedDate: timestamp (nullable = false)
#
# root
#  |-- SalesOrderID: integer (nullable = false)
#  |-- RevisionNumber: byte (nullable = false)
#  |-- OrderDate: timestamp (nullable = false)
#  |-- DueDate: timestamp (nullable = false)
#  |-- ShipDate: timestamp (nullable = true)
#  |-- Status: byte (nullable = false)
#  |-- OnlineOrderFlag: boolean (nullable = false)
#  |-- SalesOrderNumber: string (nullable = false)
#  |-- PurchaseOrderNumber: string (nullable = true)
#  |-- AccountNumber: string (nullable = true)
#  |-- CustomerID: integer (nullable = false)
#  |-- ShipToAddressID: integer (nullable = true)
#  |-- BillToAddressID: integer (nullable = true)
#  |-- ShipMethod: string (nullable = false)
#  |-- CreditCardApprovalCode: string (nullable = true)
#  |-- SubTotal: decimal(19,4) (nullable = false)
#  |-- TaxAmt: decimal(19,4) (nullable = false)
#  |-- Freight: decimal(19,4) (nullable = false)
#  |-- TotalDue: decimal(19,4) (nullable = false)
#  |-- Comment: string (nullable = true)
#  |-- rowguid: string (nullable = false)
#  |-- ModifiedDate: timestamp (nullable = false)
#  |-- ingestion_timestamp: timestamp (nullable = false)
#
# root
#  |-- SalesOrderID: integer (nullable = false)
#  |-- SalesOrderDetailID: integer (nullable = false)
#  |-- OrderQty: short (nullable = false)
#  |-- ProductID: integer (nullable = false)
#  |-- UnitPrice: decimal(19,4) (nullable = false)
#  |-- UnitPriceDiscount: decimal(19,4) (nullable = false)
#  |-- LineTotal: decimal(38,6) (nullable = false)
#  |-- rowguid: string (nullable = false)
#  |-- ModifiedDate: timestamp (nullable = false)
#  |-- ingestion_timestamp: timestamp (nullable = false)

# %%
duplicates = (
    df_address
    .groupBy(df_address.columns)
    .count()
    .filter(col("count") > 1)
)
duplicates.show()

duplicates = (
    df_customer
    .groupBy(df_customer.columns)
    .count()
    .filter(col("count") > 1)
)
duplicates.show()
duplicates = (
    df_customer_address
    .groupBy(df_customer_address.columns)
    .count()
    .filter(col("count") > 1)
)
duplicates.show()
duplicates = (
    df_product
    .groupBy(df_product.columns)
    .count()
    .filter(col("count") > 1)
)
duplicates.show()
duplicates = (
    df_product_category
    .groupBy(df_product_category.columns)
    .count()
    .filter(col("count") > 1)
)
duplicates.show()
duplicates = (
    df_product_description
    .groupBy(df_product_description.columns)
    .count()
    .filter(col("count") > 1)
)
duplicates.show()
duplicates = (
    df_product_model
    .groupBy(df_product_model.columns)
    .count()
    .filter(col("count") > 1)
)
duplicates.show()
duplicates = (
    df_product_model_description
    .groupBy(df_product_model_description.columns)
    .count()
    .filter(col("count") > 1)
)
duplicates.show()
duplicates = (
    df_sales_order_header
    .groupBy(df_sales_order_header.columns)
    .count()
    .filter(col("count") > 1)
)
duplicates.show()
duplicates = (
    df_sales_order_detail
    .groupBy(df_sales_order_detail.columns)
    .count()
    .filter(col("count") > 1)
)
duplicates.show()
# Out:
# +---------+------------+------------+----+-------------+-------------+----------+-------+------------+-------------------+-------------+------------+-----+
# |AddressID|AddressLine1|AddressLine2|City|StateProvince|CountryRegion|PostalCode|rowguid|ModifiedDate|ingestion_timestamp|source_system|source_table|count|
# +---------+------------+------------+----+-------------+-------------+----------+-------+------------+-------------------+-------------+------------+-----+
# +---------+------------+------------+----+-------------+-------------+----------+-------+------------+-------------------+-------------+------------+-----+
#
# +----------+---------+-----+---------+----------+--------+------+-----------+-----------+------------+-----+------------+------------+-------+------------+-------------------+-----+
# |CustomerID|NameStyle|Title|FirstName|MiddleName|LastName|Suffix|CompanyName|SalesPerson|EmailAddress|Phone|PasswordHash|PasswordSalt|rowguid|ModifiedDate|ingestion_timestamp|count|
# +----------+---------+-----+---------+----------+--------+------+-----------+-----------+------------+-----+------------+------------+-------+------------+-------------------+-----+
# +----------+---------+-----+---------+----------+--------+------+-----------+-----------+------------+-----+------------+------------+-------+------------+-------------------+-----+
#
# +----------+---------+-----------+-------+------------+-------------------+-----+
# |CustomerID|AddressID|AddressType|rowguid|ModifiedDate|ingestion_timestamp|count|
# +----------+---------+-----------+-------+------------+-------------------+-----+
# +----------+---------+-----------+-------+------------+-------------------+-----+
#
# +---------+----+-------------+-----+------------+---------+----+------+-----------------+--------------+-------------+-----------+----------------+--------------+----------------------+-------+------------+-------------------+-----+
# |ProductID|Name|ProductNumber|Color|StandardCost|ListPrice|Size|Weight|ProductCategoryID|ProductModelID|SellStartDate|SellEndDate|DiscontinuedDate|ThumbNailPhoto|ThumbnailPhotoFileName|rowguid|ModifiedDate|ingestion_timestamp|count|
# +---------+----+-------------+-----+------------+---------+----+------+-----------------+--------------+-------------+-----------+----------------+--------------+----------------------+-------+------------+-------------------+-----+
# +---------+----+-------------+-----+------------+---------+----+------+-----------------+--------------+-------------+-----------+----------------+--------------+----------------------+-------+------------+-------------------+-----+
#
# +-----------------+-----------------------+----+-------+------------+-------------------+-----+
# |ProductCategoryID|ParentProductCategoryID|Name|rowguid|ModifiedDate|ingestion_timestamp|count|
# +-----------------+-----------------------+----+-------+------------+-------------------+-----+
# +-----------------+-----------------------+----+-------+------------+-------------------+-----+
#
# +--------------------+-----------+-------+------------+-------------------+-----+
# |ProductDescriptionID|Description|rowguid|ModifiedDate|ingestion_timestamp|count|
# +--------------------+-----------+-------+------------+-------------------+-----+
# +--------------------+-----------+-------+------------+-------------------+-----+
#
# +--------------+----+------------------+-------+------------+-------------------+-----+
# |ProductModelID|Name|CatalogDescription|rowguid|ModifiedDate|ingestion_timestamp|count|
# +--------------+----+------------------+-------+------------+-------------------+-----+
# +--------------+----+------------------+-------+------------+-------------------+-----+
#
# +--------------+--------------------+-------+-------+------------+-----+
# |ProductModelID|ProductDescriptionID|Culture|rowguid|ModifiedDate|count|
# +--------------+--------------------+-------+-------+------------+-----+
# +--------------+--------------------+-------+-------+------------+-----+
#
# +------------+--------------+---------+-------+--------+------+---------------+----------------+-------------------+-------------+----------+---------------+---------------+----------+----------------------+--------+------+-------+--------+-------+-------+------------+-------------------+-----+
# |SalesOrderID|RevisionNumber|OrderDate|DueDate|ShipDate|Status|OnlineOrderFlag|SalesOrderNumber|PurchaseOrderNumber|AccountNumber|CustomerID|ShipToAddressID|BillToAddressID|ShipMethod|CreditCardApprovalCode|SubTotal|TaxAmt|Freight|TotalDue|Comment|rowguid|ModifiedDate|ingestion_timestamp|count|
# +------------+--------------+---------+-------+--------+------+---------------+----------------+-------------------+-------------+----------+---------------+---------------+----------+----------------------+--------+------+-------+--------+-------+-------+------------+-------------------+-----+
# +------------+--------------+---------+-------+--------+------+---------------+----------------+-------------------+-------------+----------+---------------+---------------+----------+----------------------+--------+------+-------+--------+-------+-------+------------+-------------------+-----+
#
# +------------+------------------+--------+---------+---------+-----------------+---------+-------+------------+-------------------+-----+
# |SalesOrderID|SalesOrderDetailID|OrderQty|ProductID|UnitPrice|UnitPriceDiscount|LineTotal|rowguid|ModifiedDate|ingestion_timestamp|count|
# +------------+------------------+--------+---------+---------+-----------------+---------+-------+------------+-------------------+-----+
# +------------+------------------+--------+---------+---------+-----------------+---------+-------+------------+-------------------+-----+

# %%
df_address.filter(
    col("AddressID").isNull()
).show()
# Out:
# +---------+------------+------------+----+-------------+-------------+----------+-------+------------+-------------------+-------------+------------+
# |AddressID|AddressLine1|AddressLine2|City|StateProvince|CountryRegion|PostalCode|rowguid|ModifiedDate|ingestion_timestamp|source_system|source_table|
# +---------+------------+------------+----+-------------+-------------+----------+-------+------------+-------------------+-------------+------------+
# +---------+------------+------------+----+-------------+-------------+----------+-------+------------+-------------------+-------------+------------+

# %%
for column in df_address.columns:
    df_address = df_address.withColumnRenamed(
        column,
        column.lower()
    )

df_address.printSchema()

for column in df_customer.columns:
    df_customer = df_customer.withColumnRenamed(
        column,
        column.lower()
    )

df_customer.printSchema()

for column in df_customer_address.columns:
    df_customer_address = df_customer_address.withColumnRenamed(
        column,
        column.lower()
    )

df_customer_address.printSchema()

for column in df_product.columns:
    df_product = df_product.withColumnRenamed(
        column,
        column.lower()
    )

df_product.printSchema()


for column in df_sales_order_header.columns:
    df_sales_order_header = df_sales_order_header.withColumnRenamed(
        column,
        column.lower()
    )

df_sales_order_header.printSchema()

for column in df_sales_order_detail.columns:
    df_sales_order_detail = df_sales_order_detail.withColumnRenamed(
        column,
        column.lower()
    )

df_sales_order_detail.printSchema()
# Out:
# root
#  |-- addressid: integer (nullable = false)
#  |-- addressline1: string (nullable = false)
#  |-- addressline2: string (nullable = true)
#  |-- city: string (nullable = false)
#  |-- stateprovince: string (nullable = false)
#  |-- countryregion: string (nullable = false)
#  |-- postalcode: string (nullable = false)
#  |-- rowguid: string (nullable = false)
#  |-- modifieddate: timestamp (nullable = false)
#  |-- ingestion_timestamp: timestamp (nullable = false)
#  |-- source_system: string (nullable = false)
#  |-- source_table: string (nullable = false)
#
# root
#  |-- customerid: integer (nullable = false)
#  |-- namestyle: boolean (nullable = false)
#  |-- title: string (nullable = true)
#  |-- firstname: string (nullable = false)
#  |-- middlename: string (nullable = true)
#  |-- lastname: string (nullable = false)
#  |-- suffix: string (nullable = true)
#  |-- companyname: string (nullable = true)
#  |-- salesperson: string (nullable = true)
#  |-- emailaddress: string (nullable = true)
#  |-- phone: string (nullable = true)
#  |-- passwordhash: string (nullable = false)
#  |-- passwordsalt: string (nullable = false)
#  |-- rowguid: string (nullable = false)
#  |-- modifieddate: timestamp (nullable = false)
#  |-- ingestion_timestamp: timestamp (nullable = false)
#
# root
#  |-- customerid: integer (nullable = false)
#  |-- addressid: integer (nullable = false)
#  |-- addresstype: string (nullable = false)
#  |-- rowguid: string (nullable = false)
#  |-- modifieddate: timestamp (nullable = false)
#  |-- ingestion_timestamp: timestamp (nullable = false)
#
# root
#  |-- productid: integer (nullable = false)
#  |-- name: string (nullable = false)
#  |-- productnumber: string (nullable = false)
#  |-- color: string (nullable = true)
#  |-- standardcost: decimal(19,4) (nullable = false)
#  |-- listprice: decimal(19,4) (nullable = false)
#  |-- size: string (nullable = true)
#  |-- weight: decimal(8,2) (nullable = true)
#  |-- productcategoryid: integer (nullable = true)
#  |-- productmodelid: integer (nullable = true)
#  |-- sellstartdate: timestamp (nullable = false)
#  |-- sellenddate: timestamp (nullable = true)
#  |-- discontinueddate: timestamp (nullable = true)
#  |-- thumbnailphoto: binary (nullable = true)
#  |-- thumbnailphotofilename: string (nullable = true)
#  |-- rowguid: string (nullable = false)
#  |-- modifieddate: timestamp (nullable = false)
#  |-- ingestion_timestamp: timestamp (nullable = false)
#
# root
#  |-- salesorderid: integer (nullable = false)
#  |-- revisionnumber: byte (nullable = false)
#  |-- orderdate: timestamp (nullable = false)
#  |-- duedate: timestamp (nullable = false)
#  |-- shipdate: timestamp (nullable = true)
#  |-- status: byte (nullable = false)
#  |-- onlineorderflag: boolean (nullable = false)
#  |-- salesordernumber: string (nullable = false)
#  |-- purchaseordernumber: string (nullable = true)
#  |-- accountnumber: string (nullable = true)
#  |-- customerid: integer (nullable = false)
#  |-- shiptoaddressid: integer (nullable = true)
#  |-- billtoaddressid: integer (nullable = true)
#  |-- shipmethod: string (nullable = false)
#  |-- creditcardapprovalcode: string (nullable = true)
#  |-- subtotal: decimal(19,4) (nullable = false)
#  |-- taxamt: decimal(19,4) (nullable = false)
#  |-- freight: decimal(19,4) (nullable = false)
#  |-- totaldue: decimal(19,4) (nullable = false)
#  |-- comment: string (nullable = true)
#  |-- rowguid: string (nullable = false)
#  |-- modifieddate: timestamp (nullable = false)
#  |-- ingestion_timestamp: timestamp (nullable = false)
#
# root
#  |-- salesorderid: integer (nullable = false)
#  |-- salesorderdetailid: integer (nullable = false)
#  |-- orderqty: short (nullable = false)
#  |-- productid: integer (nullable = false)
#  |-- unitprice: decimal(19,4) (nullable = false)
#  |-- unitpricediscount: decimal(19,4) (nullable = false)
#  |-- linetotal: decimal(38,6) (nullable = false)
#  |-- rowguid: string (nullable = false)
#  |-- modifieddate: timestamp (nullable = false)
#  |-- ingestion_timestamp: timestamp (nullable = false)

# %%
df_address.createOrReplaceTempView(
    "vw_address"
)
df_customer.createOrReplaceTempView(
    "vw_customer"
)
df_customer_address.createOrReplaceTempView(
    "vw_customer_address"
)
df_product.createOrReplaceTempView(
    "vw_product"
)
df_sales_order_header.createOrReplaceTempView(
    "vw_sales_order_header"
)
df_sales_order_detail.createOrReplaceTempView(
    "vw_sales_order_detail"
)

# %%
spark.sql(
    """
    SELECT *
    FROM vw_address
    """
).show()

spark.sql(
    """
    SELECT *
    FROM vw_customer
    
    """
)
spark.sql(
    """
    SELECT *
    FROM vw_customer_address
    """
).show()
spark.sql(
    """
    SELECT *
    FROM vw_product
    """
).show()
spark.sql(
    """
    SELECT *
    FROM vw_sales_order_header
    """
).show()
spark.sql(
    """
    SELECT *
    FROM vw_sales_order_detail
    """
).show()
# Out:
# +---------+--------------------+------------+---------+-------------+--------------+----------+-------+-------------------+--------------------+-------------+------------+
# |addressid|        addressline1|addressline2|     city|stateprovince| countryregion|postalcode|rowguid|       modifieddate| ingestion_timestamp|source_system|source_table|
# +---------+--------------------+------------+---------+-------------+--------------+----------+-------+-------------------+--------------------+-------------+------------+
# |        1|       1970 Napa Ct.|        NULL|  Bothell|   Washington| United States|     98011|     A1|2026-01-01 00:00:00|2026-06-11 14:56:...|     AzureSQL|     Address|
# |        2|  9833 Mt. Dias Blv.|        NULL|   Dallas|        Texas| United States|     75201|     A2|2026-01-02 00:00:00|2026-06-11 14:56:...|     AzureSQL|     Address|
# |        3|7484 Roundtree Drive|        NULL|  Toronto|      Ontario|        Canada|   M4B 1B3|     A3|2026-01-03 00:00:00|2026-06-11 14:56:...|     AzureSQL|     Address|
# |        4|    9539 Glenside Dr|        NULL|   London|      England|United Kingdom|  EC1A 1BB|     A4|2026-01-04 00:00:00|2026-06-11 14:56:...|     AzureSQL|     Address|
# |        5|       1226 Shoe St.|        NULL|Bangalore|    Karnataka|         India|    560001|     A5|2026-01-05 00:00:00|2026-06-11 14:56:...|     AzureSQL|     Address|
# +---------+--------------------+------------+---------+-------------+--------------+----------+-------+-------------------+--------------------+-------------+------------+
#
# +----------+---------+-----------+-------+-------------------+--------------------+
# |customerid|addressid|addresstype|rowguid|       modifieddate| ingestion_timestamp|
# +----------+---------+-----------+-------+-------------------+--------------------+
# |         1|        1|Main Office|    CA1|2026-01-01 00:00:00|2026-06-11 14:56:...|
# |         2|        2|   Shipping|    CA2|2026-01-02 00:00:00|2026-06-11 14:56:...|
# |         3|        3|    Billing|    CA3|2026-01-03 00:00:00|2026-06-11 14:56:...|
# |         4|        4|Main Office|    CA4|2026-01-04 00:00:00|2026-06-11 14:56:...|
# |         5|        5|   Shipping|    CA5|2026-01-05 00:00:00|2026-06-11 14:56:...|
# +----------+---------+-----------+-------+-------------------+--------------------+
#
# +---------+-------------+-------------+------+------------+---------+----+------+-----------------+--------------+-------------------+-----------+----------------+--------------+----------------------+-------+-------------------+--------------------+
# |productid|         name|productnumber| color|standardcost|listprice|size|weight|productcategoryid|productmodelid|      sellstartdate|sellenddate|discontinueddate|thumbnailphoto|thumbnailphotofilename|rowguid|       modifieddate| ingestion_timestamp|
# +---------+-------------+-------------+------+------------+---------+----+------+-----------------+--------------+-------------------+-----------+----------------+--------------+----------------------+-------+-------------------+--------------------+
# |        1|Mountain Bike|       BK-M68| Black|   1200.0000|2500.0000|   M| 15.50|                5|             2|2026-01-01 00:00:00|       NULL|            NULL|          NULL|          mountain.jpg|     P1|2026-01-01 00:00:00|2026-06-11 14:56:...|
# |        2|    Road Bike|       BK-R79|   Red|   1500.0000|3200.0000|   L| 12.80|                1|             3|2026-01-02 00:00:00|       NULL|            NULL|          NULL|              road.jpg|     P2|2026-01-02 00:00:00|2026-06-11 14:56:...|
# |        3| Touring Bike|       BK-T44|  Blue|   1000.0000|2100.0000|   M| 14.20|                1|             4|2026-01-03 00:00:00|       NULL|            NULL|          NULL|           touring.jpg|     P3|2026-01-03 00:00:00|2026-06-11 14:56:...|
# |        4| Sport Helmet|      HL-U509|Yellow|     20.0000|  49.9900|NULL|  1.20|                4|             5|2026-01-04 00:00:00|       NULL|            NULL|          NULL|            helmet.jpg|     P4|2026-01-04 00:00:00|2026-06-11 14:56:...|
# |        5| Classic Vest|      VE-C304|  Blue|     30.0000|  63.5000|   L|  0.80|                3|             1|2026-01-05 00:00:00|       NULL|            NULL|          NULL|              vest.jpg|     P5|2026-01-05 00:00:00|2026-06-11 14:56:...|
# +---------+-------------+-------------+------+------------+---------+----+------+-----------------+--------------+-------------------+-----------+----------------+--------------+----------------------+-------+-------------------+--------------------+
#
# +------------+--------------+-------------------+-------------------+-------------------+------+---------------+----------------+-------------------+--------------+----------+---------------+---------------+-----------------+----------------------+---------+--------+-------+---------+-------+-------+-------------------+--------------------+
# |salesorderid|revisionnumber|          orderdate|            duedate|           shipdate|status|onlineorderflag|salesordernumber|purchaseordernumber| accountnumber|customerid|shiptoaddressid|billtoaddressid|       shipmethod|creditcardapprovalcode| subtotal|  taxamt|freight| totaldue|comment|rowguid|       modifieddate| ingestion_timestamp|
# +------------+--------------+-------------------+-------------------+-------------------+------+---------------+----------------+-------------------+--------------+----------+---------------+---------------+-----------------+----------------------+---------+--------+-------+---------+-------+-------+-------------------+--------------------+
# |        1001|             1|2026-02-01 00:00:00|2026-02-10 00:00:00|2026-02-05 00:00:00|     5|           true|          SO1001|             PO1001|10-4020-000001|         1|              1|              1|CARGO TRANSPORT 5|              APPROVED|2500.0000|200.0000|50.0000|2750.0000|   NULL|   SOH1|2026-02-01 00:00:00|2026-06-11 14:56:...|
# |        1002|             1|2026-02-02 00:00:00|2026-02-11 00:00:00|2026-02-06 00:00:00|     5|           true|          SO1002|             PO1002|10-4020-000002|         2|              2|              2|CARGO TRANSPORT 5|              APPROVED|3200.0000|256.0000|70.0000|3526.0000|   NULL|   SOH2|2026-02-02 00:00:00|2026-06-11 14:56:...|
# |        1003|             1|2026-02-03 00:00:00|2026-02-12 00:00:00|2026-02-07 00:00:00|     5|          false|          SO1003|             PO1003|10-4020-000003|         3|              3|              3|CARGO TRANSPORT 5|              APPROVED|2100.0000|168.0000|60.0000|2328.0000|   NULL|   SOH3|2026-02-03 00:00:00|2026-06-11 14:56:...|
# +------------+--------------+-------------------+-------------------+-------------------+------+---------------+----------------+-------------------+--------------+----------+---------------+---------------+-----------------+----------------------+---------+--------+-------+---------+-------+-------+-------------------+--------------------+
#
# +------------+------------------+--------+---------+---------+-----------------+-----------+-------+-------------------+--------------------+
# |salesorderid|salesorderdetailid|orderqty|productid|unitprice|unitpricediscount|  linetotal|rowguid|       modifieddate| ingestion_timestamp|
# +------------+------------------+--------+---------+---------+-----------------+-----------+-------+-------------------+--------------------+
# |        1001|                 1|       1|        1|2500.0000|           0.0000|2500.000000|   SOD1|2026-02-01 00:00:00|2026-06-11 14:56:...|
# |        1002|                 2|       1|        2|3200.0000|           0.0000|3200.000000|   SOD2|2026-02-02 00:00:00|2026-06-11 14:56:...|
# |        1003|                 3|       1|        3|2100.0000|           0.0000|2100.000000|   SOD3|2026-02-03 00:00:00|2026-06-11 14:56:...|
# |        1001|                 4|       2|        4|  49.9900|           0.0000|  99.980000|   SOD4|2026-02-01 00:00:00|2026-06-11 14:56:...|
# |        1002|                 5|       3|        5|  63.5000|           0.0000| 190.500000|   SOD5|2026-02-02 00:00:00|2026-06-11 14:56:...|
# +------------+------------------+--------+---------+---------+-----------------+-----------+-------+-------------------+--------------------+

# %%
df_sales_order_detail = (
    df_sales_order_detail.repartition(8)
)

# %%
df_product_category = (
    df_product_category.coalesce(1)
)

# %%
df_product.select(
    "Color"
).distinct().show()
# Out:
# +------+
# | Color|
# +------+
# | Black|
# |   Red|
# |  Blue|
# |Yellow|
# +------+

# %%
df_address.filter(
    col("ModifiedDate") >= "2026-06-10"
).show()
df_customer.filter(
    col("ModifiedDate") >= "2026-06-10"
).show()
df_customer_address.filter(
    col("ModifiedDate") >= "2026-06-10"
).show()
df_product.filter(
    col("ModifiedDate") >= "2026-06-10"
).show()
df_sales_order_header.filter(
    col("ModifiedDate") >= "2026-06-10"
).show()
df_sales_order_detail.filter(
    col("ModifiedDate") >= "2026-06-10"
).show()
# Out:
# +---------+------------+------------+----+-------------+-------------+----------+-------+------------+-------------------+-------------+------------+
# |addressid|addressline1|addressline2|city|stateprovince|countryregion|postalcode|rowguid|modifieddate|ingestion_timestamp|source_system|source_table|
# +---------+------------+------------+----+-------------+-------------+----------+-------+------------+-------------------+-------------+------------+
# +---------+------------+------------+----+-------------+-------------+----------+-------+------------+-------------------+-------------+------------+
#
# +----------+---------+-----+---------+----------+--------+------+-----------+-----------+------------+-----+------------+------------+-------+------------+-------------------+
# |customerid|namestyle|title|firstname|middlename|lastname|suffix|companyname|salesperson|emailaddress|phone|passwordhash|passwordsalt|rowguid|modifieddate|ingestion_timestamp|
# +----------+---------+-----+---------+----------+--------+------+-----------+-----------+------------+-----+------------+------------+-------+------------+-------------------+
# +----------+---------+-----+---------+----------+--------+------+-----------+-----------+------------+-----+------------+------------+-------+------------+-------------------+
#
# +----------+---------+-----------+-------+------------+-------------------+
# |customerid|addressid|addresstype|rowguid|modifieddate|ingestion_timestamp|
# +----------+---------+-----------+-------+------------+-------------------+
# +----------+---------+-----------+-------+------------+-------------------+
#
# +---------+----+-------------+-----+------------+---------+----+------+-----------------+--------------+-------------+-----------+----------------+--------------+----------------------+-------+------------+-------------------+
# |productid|name|productnumber|color|standardcost|listprice|size|weight|productcategoryid|productmodelid|sellstartdate|sellenddate|discontinueddate|thumbnailphoto|thumbnailphotofilename|rowguid|modifieddate|ingestion_timestamp|
# +---------+----+-------------+-----+------------+---------+----+------+-----------------+--------------+-------------+-----------+----------------+--------------+----------------------+-------+------------+-------------------+
# +---------+----+-------------+-----+------------+---------+----+------+-----------------+--------------+-------------+-----------+----------------+--------------+----------------------+-------+------------+-------------------+
#
# +------------+--------------+---------+-------+--------+------+---------------+----------------+-------------------+-------------+----------+---------------+---------------+----------+----------------------+--------+------+-------+--------+-------+-------+------------+-------------------+
# |salesorderid|revisionnumber|orderdate|duedate|shipdate|status|onlineorderflag|salesordernumber|purchaseordernumber|accountnumber|customerid|shiptoaddressid|billtoaddressid|shipmethod|creditcardapprovalcode|subtotal|taxamt|freight|totaldue|comment|rowguid|modifieddate|ingestion_timestamp|
# +------------+--------------+---------+-------+--------+------+---------------+----------------+-------------------+-------------+----------+---------------+---------------+----------+----------------------+--------+------+-------+--------+-------+-------+------------+-------------------+
# +------------+--------------+---------+-------+--------+------+---------------+----------------+-------------------+-------------+----------+---------------+---------------+----------+----------------------+--------+------+-------+--------+-------+-------+------------+-------------------+
#
# +------------+------------------+--------+---------+---------+-----------------+---------+-------+------------+-------------------+
# |salesorderid|salesorderdetailid|orderqty|productid|unitprice|unitpricediscount|linetotal|rowguid|modifieddate|ingestion_timestamp|
# +------------+------------------+--------+---------+---------+-----------------+---------+-------+------------+-------------------+
# +------------+------------------+--------+---------+---------+-----------------+---------+-------+------------+-------------------+

# %%
audit_data = [
    (
        "Address",
        df_address.count(),
        "SUCCESS",
        datetime.now()
    )
]

audit_df = spark.createDataFrame(
    audit_data,
    [
        "table_name",
        "record_count",
        "status",
        "audit_timestamp"
    ]
)

audit_df.write \
    .format("delta") \
    .mode("overwrite") \
    .saveAsTable("bronze_audit_log")

# %%
# silver

# %%
df_customer = df_customer.dropDuplicates()
df_address = df_address.dropDuplicates()
df_product = df_product.dropDuplicates()
df_product_category=df_product_category.dropDuplicates()
df_product_description=df_product_description.dropDuplicates()
df_product_model=df_product_model.dropDuplicates()
df_product_model_description=df_product_model_description.dropDuplicates()
df_sales_order_header=df_sales_order_header.dropDuplicates()
df_sales_order_detail=df_sales_order_detail.dropDuplicates()

# %%
import re

df_address=df_address.toDF(*[
     re.sub(r'(?<!^)(?=[A-Z])', '_', c).lower()
    for c in df_customer.columns
    ])
df_customer = df_customer.toDF(*[
    re.sub(r'(?<!^)(?=[A-Z])', '_', c).lower()
    for c in df_customer.columns
])
df_customer_address = df_customer_address.toDF(*[
    re.sub(r'(?<!^)(?=[A-Z])', '_', c).lower()
    for c in df_customer_address.columns
])
df_product = df_product.toDF(*[
    re.sub(r'(?<!^)(?=[A-Z])', '_', c).lower()
    for c in df_product.columns
])
df_product_category = df_product_category.toDF(*[
    re.sub(r'(?<!^)(?=[A-Z])', '_', c).lower()
    for c in df_product_category.columns
])
df_product_description = df_product_description.toDF(*[
    re.sub(r'(?<!^)(?=[A-Z])', '_', c).lower()
    for c in df_product_description.columns
])
df_product_model = df_product_model.toDF(*[
    re.sub(r'(?<!^)(?=[A-Z])', '_', c).lower()
    for c in df_product_model.columns
])
df_product_model_description = df_product_model_description.toDF(*[
    re.sub(r'(?<!^)(?=[A-Z])', '_', c).lower()
    for c in df_product_model_description.columns
])
df_sales_order_detail=df_sales_order_detail.toDF(*[
    re.sub(r'(?<!^)(?=[A-Z])', '_', c).lower()
    for c in df_sales_order_detail.columns
])
df_sales_order_header=df_sales_order_header.toDF(*[
    re.sub(r'(?<!^)(?=[A-Z])', '_', c).lower()
    for c in df_sales_order_header.columns
])

# %%
from pyspark.sql.functions import to_date

df_sales_order_header = (
    df_sales_order_header
    .withColumn(
        "order_date",
        to_date("OrderDate")
    )
)
df_customer = df_customer.withColumn("modified_date", to_date("modifieddate")) \
       .withColumn("ingestion_timestamp", to_timestamp("ingestion_timestamp"))
df_address = df_address.withColumn("modified_date", to_date("modifieddate")) \
       .withColumn("ingestion_timestamp", to_timestamp("ingestion_timestamp"))
df_customer_address = df_customer_address.withColumn("modified_date", to_date("modifieddate")) \
       .withColumn("ingestion_timestamp", to_timestamp("ingestion_timestamp"))
df_product = df_product.withColumn("modified_date", to_date("modifieddate")) \
       .withColumn("ingestion_timestamp", to_timestamp("ingestion_timestamp"))
df_product_category = df_product_category.withColumn("modified_date", to_date("modified_date")) \
       .withColumn("ingestion_timestamp", to_timestamp("ingestion_timestamp"))
df_product_description = df_product_description.withColumn("modified_date", to_date("modified_date")) \
       .withColumn("ingestion_timestamp", to_timestamp("ingestion_timestamp"))
df_product_model_product_description = df_product_model_description.withColumn("modified_date", to_date("modified_date")) \
       .withColumn("ingestion_timestamp", to_timestamp("ingestion_timestamp"))
df_sales_order_detail = df_sales_order_detail.withColumn("modified_date", to_date("modifieddate")) \
       .withColumn("ingestion_timestamp", to_timestamp("ingestion_timestamp"))
df_sales_order_header = df_sales_order_header.withColumn("order_date", to_date("orderdate")) \
       .withColumn("ingestion_timestamp", to_timestamp("ingestion_timestamp"))

# %%
df_customer = df_customer.fillna({
    "Title": "Unknown",
    "MiddleName": "",
    "Suffix": ""
})

# %%
from pyspark.sql.functions import lower

df_customer = (
    df_customer
    .withColumn(
        "EmailAddress",
        lower("EmailAddress")
    )
)
df_sales_order_detail=(
    df_sales_order_detail
    .withColumn(
        "EmailAddress",
        lower("EmailAddress")
    )
)

# %%
from pyspark.sql.functions import concat_ws

df_customer = (
    df_customer
    .withColumn(
        "FullName",
        concat_ws(
            " ",
            "FirstName",
            "MiddleName",
            "LastName"
        )
    )
)

# %%
from pyspark.sql.functions import split

df_address = (
    df_address
    .withColumn(
        "AddressPart1",
        split("AddressLine1", " ").getItem(0)
    )
    .withColumn(
        "AddressPart2",
        split("AddressLine1", " ").getItem(1)
    )
)

# %%
from pyspark.sql.functions import year, month, dayofmonth

df_sales_order_header = (
    df_sales_order_header
    .withColumn(
        "OrderYear",
        year("OrderDate")
    )
    .withColumn(
        "OrderMonth",
        month("OrderDate")
    )
    .withColumn(
        "OrderDay",
        dayofmonth("OrderDate")
    )
)

# %%
from pyspark.sql.functions import col

valid_orders = (
    df_sales_order_header
    .filter(col("TotalDue") > 0)
)
valid_orders.show()
# Out:
# +------------+--------------+-------------------+-------------------+-------------------+------+---------------+----------------+-------------------+--------------+----------+---------------+---------------+-----------------+----------------------+---------+--------+-------+---------+-------+-------+-------------------+--------------------+----------+---------+----------+--------+
# |salesorderid|revisionnumber|          orderdate|            duedate|           shipdate|status|onlineorderflag|salesordernumber|purchaseordernumber| accountnumber|customerid|shiptoaddressid|billtoaddressid|       shipmethod|creditcardapprovalcode| subtotal|  taxamt|freight| totaldue|comment|rowguid|       modifieddate| ingestion_timestamp|order_date|OrderYear|OrderMonth|OrderDay|
# +------------+--------------+-------------------+-------------------+-------------------+------+---------------+----------------+-------------------+--------------+----------+---------------+---------------+-----------------+----------------------+---------+--------+-------+---------+-------+-------+-------------------+--------------------+----------+---------+----------+--------+
# |        1001|             1|2026-02-01 00:00:00|2026-02-10 00:00:00|2026-02-05 00:00:00|     5|           true|          SO1001|             PO1001|10-4020-000001|         1|              1|              1|CARGO TRANSPORT 5|              APPROVED|2500.0000|200.0000|50.0000|2750.0000|   NULL|   SOH1|2026-02-01 00:00:00|2026-06-11 14:56:...|2026-02-01|     2026|         2|       1|
# |        1002|             1|2026-02-02 00:00:00|2026-02-11 00:00:00|2026-02-06 00:00:00|     5|           true|          SO1002|             PO1002|10-4020-000002|         2|              2|              2|CARGO TRANSPORT 5|              APPROVED|3200.0000|256.0000|70.0000|3526.0000|   NULL|   SOH2|2026-02-02 00:00:00|2026-06-11 14:56:...|2026-02-02|     2026|         2|       2|
# |        1003|             1|2026-02-03 00:00:00|2026-02-12 00:00:00|2026-02-07 00:00:00|     5|          false|          SO1003|             PO1003|10-4020-000003|         3|              3|              3|CARGO TRANSPORT 5|              APPROVED|2100.0000|168.0000|60.0000|2328.0000|   NULL|   SOH3|2026-02-03 00:00:00|2026-06-11 14:56:...|2026-02-03|     2026|         2|       3|
# +------------+--------------+-------------------+-------------------+-------------------+------+---------------+----------------+-------------------+--------------+----------+---------------+---------------+-----------------+----------------------+---------+--------+-------+---------+-------+-------+-------------------+--------------------+----------+---------+----------+--------+

# %%
customer_address_df = (
    df_customer.alias("c")
    .join(
        df_customer_address.alias("ca"),
        "CustomerID",
        "inner"
    )
)

customer_address_df.show()
# Out:
# +----------+---------+-----+---------+----------+----------+------+--------------------+--------------------+-------------------+------------+------------+------------+-------+-------------------+--------------------+-------------+-----------------+---------+-----------+-------+-------------------+--------------------+-------------+
# |customerid|namestyle|title|firstname|middlename|  lastname|suffix|         companyname|         salesperson|       EmailAddress|       phone|passwordhash|passwordsalt|rowguid|       modifieddate| ingestion_timestamp|modified_date|         FullName|addressid|addresstype|rowguid|       modifieddate| ingestion_timestamp|modified_date|
# +----------+---------+-----+---------+----------+----------+------+--------------------+--------------------+-------------------+------------+------------+------------+-------+-------------------+--------------------+-------------+-----------------+---------+-----------+-------+-------------------+--------------------+-------------+
# |         1|    false|  Mr.|  Orlando|        N.|       Gee|      |        A Bike Store|adventure-works\p...|orlando@example.com|245-555-0173|       hash1|       salt1|     C1|2026-01-01 00:00:00|2026-06-11 14:56:...|   2026-01-01|   Orlando N. Gee|        1|Main Office|    CA1|2026-01-01 00:00:00|2026-06-11 14:56:...|   2026-01-01|
# |         2|    false|  Mr.|    Keith|          |    Harris|      |  Progressive Sports|adventure-works\d...|  keith@example.com|170-555-0127|       hash2|       salt2|     C2|2026-01-02 00:00:00|2026-06-11 14:56:...|   2026-01-02|    Keith  Harris|        2|   Shipping|    CA2|2026-01-02 00:00:00|2026-06-11 14:56:...|   2026-01-02|
# |         3|    false|  Ms.|    Donna|        F.|  Carreras|      |Advanced Bike Com...|adventure-works\j...|  donna@example.com|279-555-0130|       hash3|       salt3|     C3|2026-01-03 00:00:00|2026-06-11 14:56:...|   2026-01-03|Donna F. Carreras|        3|    Billing|    CA3|2026-01-03 00:00:00|2026-06-11 14:56:...|   2026-01-03|
# |         4|    false|  Mr.|   Janeth|          |   Esteves|      |Modular Cycle Sys...|adventure-works\g...| janeth@example.com|710-555-0173|       hash4|       salt4|     C4|2026-01-04 00:00:00|2026-06-11 14:56:...|   2026-01-04|  Janeth  Esteves|        4|Main Office|    CA4|2026-01-04 00:00:00|2026-06-11 14:56:...|   2026-01-04|
# |         5|    false|  Ms.|     Lucy|          |Harrington|      | Metropolitan Sports|adventure-works\j...|   lucy@example.com|828-555-0188|       hash5|       salt5|     C5|2026-01-05 00:00:00|2026-06-11 14:56:...|   2026-01-05| Lucy  Harrington|        5|   Shipping|    CA5|2026-01-05 00:00:00|2026-06-11 14:56:...|   2026-01-05|
# +----------+---------+-----+---------+----------+----------+------+--------------------+--------------------+-------------------+------------+------------+------------+-------+-------------------+--------------------+-------------+-----------------+---------+-----------+-------+-------------------+--------------------+-------------+

# %%
df_product_category.show()
df_product.show()
# Out:
# +--------------------+---------------------------+--------------+-------+-------------+--------------------+
# |product_category_i_d|parent_product_category_i_d|          name|rowguid|modified_date| ingestion_timestamp|
# +--------------------+---------------------------+--------------+-------+-------------+--------------------+
# |                   1|                       NULL|         Bikes|    PC1|   2026-01-01|2026-06-11 14:56:...|
# |                   2|                       NULL|    Components|    PC2|   2026-01-02|2026-06-11 14:56:...|
# |                   3|                       NULL|      Clothing|    PC3|   2026-01-03|2026-06-11 14:56:...|
# |                   4|                       NULL|   Accessories|    PC4|   2026-01-04|2026-06-11 14:56:...|
# |                   5|                          1|Mountain Bikes|    PC5|   2026-01-05|2026-06-11 14:56:...|
# +--------------------+---------------------------+--------------+-------+-------------+--------------------+
#
# +---------+-------------+-------------+------+------------+---------+----+------+-----------------+--------------+-------------------+-----------+----------------+--------------+----------------------+-------+-------------------+--------------------+-------------+
# |productid|         name|productnumber| color|standardcost|listprice|size|weight|productcategoryid|productmodelid|      sellstartdate|sellenddate|discontinueddate|thumbnailphoto|thumbnailphotofilename|rowguid|       modifieddate| ingestion_timestamp|modified_date|
# +---------+-------------+-------------+------+------------+---------+----+------+-----------------+--------------+-------------------+-----------+----------------+--------------+----------------------+-------+-------------------+--------------------+-------------+
# |        1|Mountain Bike|       BK-M68| Black|   1200.0000|2500.0000|   M| 15.50|                5|             2|2026-01-01 00:00:00|       NULL|            NULL|          NULL|          mountain.jpg|     P1|2026-01-01 00:00:00|2026-06-11 14:56:...|   2026-01-01|
# |        2|    Road Bike|       BK-R79|   Red|   1500.0000|3200.0000|   L| 12.80|                1|             3|2026-01-02 00:00:00|       NULL|            NULL|          NULL|              road.jpg|     P2|2026-01-02 00:00:00|2026-06-11 14:56:...|   2026-01-02|
# |        3| Touring Bike|       BK-T44|  Blue|   1000.0000|2100.0000|   M| 14.20|                1|             4|2026-01-03 00:00:00|       NULL|            NULL|          NULL|           touring.jpg|     P3|2026-01-03 00:00:00|2026-06-11 14:56:...|   2026-01-03|
# |        4| Sport Helmet|      HL-U509|Yellow|     20.0000|  49.9900|NULL|  1.20|                4|             5|2026-01-04 00:00:00|       NULL|            NULL|          NULL|            helmet.jpg|     P4|2026-01-04 00:00:00|2026-06-11 14:56:...|   2026-01-04|
# |        5| Classic Vest|      VE-C304|  Blue|     30.0000|  63.5000|   L|  0.80|                3|             1|2026-01-05 00:00:00|       NULL|            NULL|          NULL|              vest.jpg|     P5|2026-01-05 00:00:00|2026-06-11 14:56:...|   2026-01-05|
# +---------+-------------+-------------+------+------------+---------+----+------+-----------------+--------------+-------------------+-----------+----------------+--------------+----------------------+-------+-------------------+--------------------+-------------+

# %%
product_model_desc_df = (
    df_product_model.alias("pm")
    .join(
        df_product_model_description.alias("pmd"),
        "product_model_i_d",
        "inner"
    )
    .join(
        df_product_description.alias("pd"),
        "product_description_i_d",
        "inner"
    )
)

product_model_desc_df.show()
# Out:
# +-----------------------+-----------------+------------+--------------------+-------+-------------------+--------------------+-------+-------+-------------------+--------------------+-------+-------------+--------------------+
# |product_description_i_d|product_model_i_d|        name| catalog_description|rowguid|      modified_date| ingestion_timestamp|culture|rowguid|      modified_date|         description|rowguid|modified_date| ingestion_timestamp|
# +-----------------------+-----------------+------------+--------------------+-------+-------------------+--------------------+-------+-------+-------------------+--------------------+-------+-------------+--------------------+
# |                      1|                2|Mountain-100|High performance ...|    PM2|2026-01-02 00:00:00|2026-06-11 14:56:...|     en|  PMPD1|2026-01-01 00:00:00|High quality moun...|    PD1|   2026-01-01|2026-06-11 14:56:...|
# |                      2|                3|    Road-150|    Road racing bike|    PM3|2026-01-03 00:00:00|2026-06-11 14:56:...|     en|  PMPD2|2026-01-02 00:00:00|Fast road bike fo...|    PD2|   2026-01-02|2026-06-11 14:56:...|
# |                      3|                4|Touring-2000|  Touring bike model|    PM4|2026-01-04 00:00:00|2026-06-11 14:56:...|     en|  PMPD3|2026-01-03 00:00:00|Comfortable touri...|    PD3|   2026-01-03|2026-06-11 14:56:...|
# |                      4|                5|Sport Helmet|        Helmet model|    PM5|2026-01-05 00:00:00|2026-06-11 14:56:...|     en|  PMPD4|2026-01-04 00:00:00|Durable sport helmet|    PD4|   2026-01-04|2026-06-11 14:56:...|
# |                      5|                1|Classic Vest|Lightweight vest ...|    PM1|2026-01-01 00:00:00|2026-06-11 14:56:...|     en|  PMPD5|2026-01-05 00:00:00|Classic blue cycl...|    PD5|   2026-01-05|2026-06-11 14:56:...|
# +-----------------------+-----------------+------------+--------------------+-------+-------------------+--------------------+-------+-------+-------------------+--------------------+-------+-------------+--------------------+

# %%
from pyspark.sql.functions import coalesce, lit

df_product = (
    df_product
    .withColumn(
        "product_category_i_d",
        coalesce(
            col("product_category_i_d"),
            lit(0)
        )
    )
)

# %%
from pyspark.sql.window import Window
from pyspark.sql.functions import row_number

window_spec = Window.partitionBy(
    "CustomerID"
).orderBy(
    col("OrderDate").desc()
)

customer_orders_ranked = (
    df_sales_order_header
    .withColumn(
        "OrderRank",
        row_number().over(window_spec)
    )
)

customer_orders_ranked.show()
# Out:
# +------------+--------------+-------------------+-------------------+-------------------+------+---------------+----------------+-------------------+--------------+----------+---------------+---------------+-----------------+----------------------+---------+--------+-------+---------+-------+-------+-------------------+--------------------+----------+---------+----------+--------+---------+
# |salesorderid|revisionnumber|          orderdate|            duedate|           shipdate|status|onlineorderflag|salesordernumber|purchaseordernumber| accountnumber|customerid|shiptoaddressid|billtoaddressid|       shipmethod|creditcardapprovalcode| subtotal|  taxamt|freight| totaldue|comment|rowguid|       modifieddate| ingestion_timestamp|order_date|OrderYear|OrderMonth|OrderDay|OrderRank|
# +------------+--------------+-------------------+-------------------+-------------------+------+---------------+----------------+-------------------+--------------+----------+---------------+---------------+-----------------+----------------------+---------+--------+-------+---------+-------+-------+-------------------+--------------------+----------+---------+----------+--------+---------+
# |        1001|             1|2026-02-01 00:00:00|2026-02-10 00:00:00|2026-02-05 00:00:00|     5|           true|          SO1001|             PO1001|10-4020-000001|         1|              1|              1|CARGO TRANSPORT 5|              APPROVED|2500.0000|200.0000|50.0000|2750.0000|   NULL|   SOH1|2026-02-01 00:00:00|2026-06-11 14:56:...|2026-02-01|     2026|         2|       1|        1|
# |        1002|             1|2026-02-02 00:00:00|2026-02-11 00:00:00|2026-02-06 00:00:00|     5|           true|          SO1002|             PO1002|10-4020-000002|         2|              2|              2|CARGO TRANSPORT 5|              APPROVED|3200.0000|256.0000|70.0000|3526.0000|   NULL|   SOH2|2026-02-02 00:00:00|2026-06-11 14:56:...|2026-02-02|     2026|         2|       2|        1|
# |        1003|             1|2026-02-03 00:00:00|2026-02-12 00:00:00|2026-02-07 00:00:00|     5|          false|          SO1003|             PO1003|10-4020-000003|         3|              3|              3|CARGO TRANSPORT 5|              APPROVED|2100.0000|168.0000|60.0000|2328.0000|   NULL|   SOH3|2026-02-03 00:00:00|2026-06-11 14:56:...|2026-02-03|     2026|         2|       3|        1|
# +------------+--------------+-------------------+-------------------+-------------------+------+---------------+----------------+-------------------+--------------+----------+---------------+---------------+-----------------+----------------------+---------+--------+-------+---------+-------+-------+-------------------+--------------------+----------+---------+----------+--------+---------+

# %%
from pyspark.sql.functions import rank

address_window = Window.partitionBy(
    "CustomerID"
).orderBy(
    col("ModifiedDate").desc()
)

latest_customer_address = (
    df_customer_address
    .withColumn(
        "AddressRank",
        rank().over(address_window)
    )
    .filter(col("AddressRank") == 1)
)

latest_customer_address.show()
# Out:
# +----------+---------+-----------+-------+-------------------+--------------------+-------------+-----------+
# |customerid|addressid|addresstype|rowguid|       modifieddate| ingestion_timestamp|modified_date|AddressRank|
# +----------+---------+-----------+-------+-------------------+--------------------+-------------+-----------+
# |         1|        1|Main Office|    CA1|2026-01-01 00:00:00|2026-06-11 14:56:...|   2026-01-01|          1|
# |         2|        2|   Shipping|    CA2|2026-01-02 00:00:00|2026-06-11 14:56:...|   2026-01-02|          1|
# |         3|        3|    Billing|    CA3|2026-01-03 00:00:00|2026-06-11 14:56:...|   2026-01-03|          1|
# |         4|        4|Main Office|    CA4|2026-01-04 00:00:00|2026-06-11 14:56:...|   2026-01-04|          1|
# |         5|        5|   Shipping|    CA5|2026-01-05 00:00:00|2026-06-11 14:56:...|   2026-01-05|          1|
# +----------+---------+-----------+-------+-------------------+--------------------+-------------+-----------+

# %%
df_customer.write \
    .format("delta") \
    .mode("overwrite") \
    .saveAsTable("silver_customer")
df_customer_address.write \
    .format("delta") \
    .mode("overwrite") \
    .saveAsTable("silver_customer_address")

df_product_description.write \
    .format("delta") \
    .mode("overwrite") \
    .saveAsTable("silver_product_description")

df_product_model_description.write \
    .format("delta") \
    .mode("overwrite") \
    .saveAsTable("silver_product_model_description")

df_sales_order_header.write \
    .format("delta") \
    .mode("overwrite") \
    .saveAsTable("sales_order_header")

# %%
# gold

# %%
customer_sales_summary = (
    df_sales_order_header
    .groupBy("customerid")
    .agg(
        sum("TotalDue").alias("TotalRevenue")
    )
)

customer_sales_summary.show()
# Out:
# +----------+------------+
# |customerid|TotalRevenue|
# +----------+------------+
# |         1|   2750.0000|
# |         2|   3526.0000|
# |         3|   2328.0000|
# +----------+------------+

# %%
monthly_sales_report = (
    df_sales_order_header
    .groupBy(
        year("orderdate").alias("Year")
    )
    .agg(
        sum("TotalDue").alias("Revenue")
    )
)

monthly_sales_report.show()
# Out:
# +----+---------+
# |Year|  Revenue|
# +----+---------+
# |2026|8604.0000|
# +----+---------+

# %%
top_10_customers = (
    customer_sales_summary
    .orderBy(desc("TotalRevenue"))
    .limit(10)
)

top_10_customers.show()
# Out:
# +----------+------------+
# |customerid|TotalRevenue|
# +----------+------------+
# |         2|   3526.0000|
# |         1|   2750.0000|
# |         3|   2328.0000|
# +----------+------------+

# %%
customer_orders = (
    df_sales_order_header
    .groupBy("CustomerID")
    .agg(
        countDistinct("SalesOrderID")
        .alias("OrderCount")
    )
)

customer_orders.show()
# Out:
# +----------+----------+
# |CustomerID|OrderCount|
# +----------+----------+
# |         1|         1|
# |         2|         1|
# |         3|         1|
# +----------+----------+

# %%
avg_order_value = (
    df_sales_order_header
    .agg(
        avg("TotalDue")
        .alias("AverageOrderValue")
    )
)

avg_order_value.show()
# Out:
# +-----------------+
# |AverageOrderValue|
# +-----------------+
# |    2868.00000000|
# +-----------------+

# %%
customers_without_orders = (
    df_customer
    .join(
        df_sales_order_header,
        "CustomerID",
        "left_anti"
    )
)

customers_without_orders.show()
# Out:
# +----------+---------+-----+---------+----------+----------+------+--------------------+--------------------+------------------+------------+------------+------------+-------+-------------------+--------------------+-------------+----------------+
# |customerid|namestyle|title|firstname|middlename|  lastname|suffix|         companyname|         salesperson|      EmailAddress|       phone|passwordhash|passwordsalt|rowguid|       modifieddate| ingestion_timestamp|modified_date|        FullName|
# +----------+---------+-----+---------+----------+----------+------+--------------------+--------------------+------------------+------------+------------+------------+-------+-------------------+--------------------+-------------+----------------+
# |         4|    false|  Mr.|   Janeth|          |   Esteves|      |Modular Cycle Sys...|adventure-works\g...|janeth@example.com|710-555-0173|       hash4|       salt4|     C4|2026-01-04 00:00:00|2026-06-11 14:56:...|   2026-01-04| Janeth  Esteves|
# |         5|    false|  Ms.|     Lucy|          |Harrington|      | Metropolitan Sports|adventure-works\j...|  lucy@example.com|828-555-0188|       hash5|       salt5|     C5|2026-01-05 00:00:00|2026-06-11 14:56:...|   2026-01-05|Lucy  Harrington|
# +----------+---------+-----+---------+----------+----------+------+--------------------+--------------------+------------------+------------+------------+------------+-------+-------------------+--------------------+-------------+----------------+

# %%
daily_sales_kpi = (
    df_sales_order_header
    .groupBy(
        to_date("OrderDate")
        .alias("OrderDate")
    )
    .agg(
        sum("TotalDue").alias("Revenue"),
        countDistinct("SalesOrderID").alias("Orders")
    )
)

daily_sales_kpi.show()
# Out:
# +----------+---------+------+
# | OrderDate|  Revenue|Orders|
# +----------+---------+------+
# |2026-02-01|2750.0000|     1|
# |2026-02-02|3526.0000|     1|
# |2026-02-03|2328.0000|     1|
# +----------+---------+------+

# %%
yearly_revenue = (
    df_sales_order_header
    .groupBy(
        year("OrderDate").alias("Year")
    )
    .agg(
        sum("TotalDue").alias("Revenue")
    )
)

yearly_revenue.show()
# Out:
# +----+---------+
# |Year|  Revenue|
# +----+---------+
# |2026|8604.0000|
# +----+---------+

# %%
profit_report = (
    yearly_revenue
    .withColumn(
        "Profit",
        col("Revenue") * 0.20
    )
)

profit_report.show()
# Out:
# +----+---------+------------------+
# |Year|  Revenue|            Profit|
# +----+---------+------------------+
# |2026|8604.0000|1720.8000000000002|
# +----+---------+------------------+

# %%
monthly_revenue = (
    df_sales_order_header
    .groupBy(
        year("OrderDate").alias("Year"),
        month("OrderDate").alias("Month")
    )
    .agg(
        sum("TotalDue").alias("Revenue")
    )
)

window_spec = Window.partitionBy(
    "Year"
).orderBy(
    desc("Revenue")
)

highest_revenue_month = (
    monthly_revenue
    .withColumn(
        "Rank",
        rank().over(window_spec)
    )
    .filter(col("Rank") == 1)
)

highest_revenue_month.show()
# Out:
# +----+-----+---------+----+
# |Year|Month|  Revenue|Rank|
# +----+-----+---------+----+
# |2026|    2|8604.0000|   1|
# +----+-----+---------+----+
