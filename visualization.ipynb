# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=sns.load_dataset('titanic')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
age =df['age'].iloc[0:5].values
age
# Out:
# array([22., 38., 26., 35., 35.])

# %%
plt.plot(df['age'])

# %%
# plt.figure(figsize=(20,5))

plt.plot(df['age'].iloc[0:5],color='r',marker='o',markeredgecolor='b',markerfacecolor='w',linewidth=1,alpha=0.9,markersize=10)


plt.xlabel('index')
plt.ylabel('age')
plt.title('xlabel vs age')



plt.ylim(10,30)
plt.xlim(10,30)
# Out:
# (10.0, 30.0)

# %%
plt.figure(figsize=(20,5))
plt.plot(df['age'])

# %%
(df[df['age']<10].shape[0]/df.shape[0])*100
# Out:
# 6.958473625140292

# %%
(df[(df['age']>20) & (df['age']<40)].shape[0]/df.shape[0])*100
# Out:
# 41.75084175084175

# %%
plt.subplot(2,2,1)
plt.plot(df['age'].iloc[0:5],color='b')
plt.plot(df['age'].iloc[6:10],color='b')
plt.subplot(2,2,2)
plt.plot(df['age'].iloc[0:5],color='g')
plt.subplot(2,2,3)
plt.plot(df['age'].iloc[0:5],color='r')
plt.subplot(2,2,4)
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
plt.scatter(df['age'],df['fare'])

# %%
(df[df['fare']<100].shape[0]/df.shape[0])*100
# Out:
# 94.05162738496072

# %%
df[df['fare']<100]['age'].value_counts()
# Out:
# age
# 24.0    28
# 22.0    25
# 28.0    25
# 30.0    24
# 19.0    24
#         ..
# 12.0     1
# 23.5     1
# 36.5     1
# 55.5     1
# 74.0     1
# Name: count, Length: 87, dtype: int64

# %%
plt.bar(df['class'],df['fare'])
# Out:
# <BarContainer object of 891 artists>

# %%
plt.barh(df['class'],df['fare'])
# Out:
# <BarContainer object of 891 artists>

# %%
plt.hist(df['age'])
# Out:
# (array([ 54.,  46., 177., 169., 118.,  70.,  45.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(df['age'].fillna(df['age'].median()))
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x23e325ee5d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x23e325ee850>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x23e325ee490>],
#  'medians': [<matplotlib.lines.Line2D at 0x23e325eead0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x23e325eec10>],
#  'means': []}

# %%
df['class'].value_counts()
# Out:
# class
# Third     491
# First     216
# Second    184
# Name: count, dtype: int64

# %%
ip=df['class'].value_counts().index

# %%
op=df['class'].value_counts().values

# %%
plt.pie(op,labels=ip,autopct= '%1.5f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x23e32c62350>,
# ...
#  [Text(-0.17571619097547903, 1.085874679799225, 'Third'),
#   Text(-0.5160760536623383, -0.9714244730478574, 'First'),
#   Text(0.8765111790709129, -0.6646263258130227, 'Second')],
#  [Text(-0.09584519507753402, 0.5922952798904862, '55.10662%'),
#   Text(-0.2814960292703663, -0.5298678943897404, '24.24242%'),
#   Text(0.47809700676595246, -0.3625234504434669, '20.65096%')])

# %%
plt.violinplot(df['age'].fillna(df['age'].mean()))
# Out:
# {'bodies': [<matplotlib.collections.FillBetweenPolyCollection at 0x23e3564a350>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x23e3564a490>,
#  'cmins': <matplotlib.collections.LineCollection at 0x23e3564a5d0>,
#  'cbars': <matplotlib.collections.LineCollection at 0x23e3564a710>}

# %%
import numpy as np
data=np.random.randint(0,100,(10,10))

# %%
plt.imshow(data)
plt.colorbar()

# %%
plt.imshow(data,cmap='inferno')
plt.colorbar()

# %%
titanic=df

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=titanic,x='survived')
plt.title('title')
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.boxplot(data=titanic,x='class')
plt.title('title')
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.scatterplot(data=titanic,x='age',y='fare',hue='survived')
plt.title('title')
plt.show()

# %%
# plt.figure(figsize=(6,8))
sns.heatmap(data,annot=True,linewidths=2,linecolor='g')
# Out:
# <Axes: >
