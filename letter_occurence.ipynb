# %%
word= str(input())
# word=word.split()
ans={}
for i in word:
    if(i == ' '): continue
    if(i in ans):
        ans[i]=ans[i]+1
    else:
        ans[i]=1
ans
# Out:
# {'h': 1, 'e': 1, 'l': 3, 'o': 2, 'w': 1, 'r': 1, 'd': 1}
